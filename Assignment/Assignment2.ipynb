# %% [markdown]
# Tokenization

# %%
import os
import nltk
from nltk.tokenize import word_tokenize
from collections import Counter

# Download nltk tokenizer if not already installed
nltk.download('punkt')

# Path to the folder containing the text files
folder_path = 'Data'

# Initialize variables to store tokens for the entire corpus
corpus_tokens = []
corpus_unique_tokens = set()

# Function to read and tokenize a single document
def tokenize_document(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
        # Tokenize the content
        tokens = word_tokenize(content)
        return tokens

# Process each document in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.txt'):
        file_path = os.path.join(folder_path, filename)
        tokens = tokenize_document(file_path)
        
        # Count tokens and unique tokens for each document
        num_tokens = len(tokens)
        num_unique_tokens = len(set(tokens))
        print(f"Document: {filename}")
        print(f"  Number of tokens: {num_tokens}")
        print(f"  Number of unique tokens: {num_unique_tokens}\n")
        
        # Add tokens to the corpus
        corpus_tokens.extend(tokens)
        corpus_unique_tokens.update(tokens)

# Summary for the entire corpus
corpus_num_tokens = len(corpus_tokens)
corpus_num_unique_tokens = len(corpus_unique_tokens)

print("Corpus Summary:")
print(f"  Total tokens in corpus: {corpus_num_tokens}")
print(f"  Total unique tokens in corpus: {corpus_num_unique_tokens}")
# Out:
# Document: a1.txt
#   Number of tokens: 1945
#   Number of unique tokens: 673
#
# Document: a10.txt
#   Number of tokens: 1448
#   Number of unique tokens: 567
#
# Document: a2.txt
#   Number of tokens: 4888
#   Number of unique tokens: 1343
#
# Document: a3.txt
#   Number of tokens: 2191
#   Number of unique tokens: 747
#
# Document: a4.txt
#   Number of tokens: 3364
#   Number of unique tokens: 1037
#
# Document: a5.txt
#   Number of tokens: 3466
#   Number of unique tokens: 1109
#
# Document: a6.txt
#   Number of tokens: 1782
#   Number of unique tokens: 643
#
# Document: a7.txt
#   Number of tokens: 1643
#   Number of unique tokens: 630
#
# Document: a8.txt
#   Number of tokens: 1836
#   Number of unique tokens: 703
#
# Document: a9.txt
#   Number of tokens: 1602
#   Number of unique tokens: 607
#
# Corpus Summary:
#   Total tokens in corpus: 24165
#   Total unique tokens in corpus: 4105
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Shalritvik\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Stopword Removal

# %%
nltk.download('punkt')
nltk.download('stopwords')

# Load the list of English stop words
stop_words = set(stopwords.words('english'))

# Path to the folder containing the text files
folder_path = 'Data'

# Initialize variables to store tokens for the entire corpus
corpus_tokens_no_stopwords = []
corpus_unique_tokens_no_stopwords = set()

# Function to read, tokenize, and remove stop words from a single document
def tokenize_and_remove_stopwords(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
        # Tokenize the content
        tokens = word_tokenize(content)
        # Remove stop words
        filtered_tokens = [token.lower() for token in tokens if token.lower() not in stop_words]
        return filtered_tokens

# Process each document in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.txt'):
        file_path = os.path.join(folder_path, filename)
        filtered_tokens = tokenize_and_remove_stopwords(file_path)
        
        # Count tokens and unique tokens for each document after removing stop words
        num_tokens_no_stopwords = len(filtered_tokens)
        num_unique_tokens_no_stopwords = len(set(filtered_tokens))
        print(f"Document: {filename}")
        print(f"  Number of tokens (after stop word removal): {num_tokens_no_stopwords}")
        print(f"  Number of unique tokens (after stop word removal): {num_unique_tokens_no_stopwords}\n")
        
        # Add filtered tokens to the corpus
        corpus_tokens_no_stopwords.extend(filtered_tokens)
        corpus_unique_tokens_no_stopwords.update(filtered_tokens)

# Summary for the entire corpus
corpus_num_tokens_no_stopwords = len(corpus_tokens_no_stopwords)
corpus_num_unique_tokens_no_stopwords = len(corpus_unique_tokens_no_stopwords)

print("Corpus Summary After Removing Stop Words:")
print(f"  Total tokens in corpus (after stop word removal): {corpus_num_tokens_no_stopwords}")
print(f"  Total unique tokens in corpus (after stop word removal): {corpus_num_unique_tokens_no_stopwords}")
# Out:
# Document: a1.txt
#   Number of tokens (after stop word removal): 1244
#   Number of unique tokens (after stop word removal): 545
#
# Document: a10.txt
#   Number of tokens (after stop word removal): 927
#   Number of unique tokens (after stop word removal): 473
#
# Document: a2.txt
#   Number of tokens (after stop word removal): 3082
#   Number of unique tokens (after stop word removal): 1152
#
# Document: a3.txt
#   Number of tokens (after stop word removal): 1382
#   Number of unique tokens (after stop word removal): 639
#
# Document: a4.txt
#   Number of tokens (after stop word removal): 2196
#   Number of unique tokens (after stop word removal): 885
#
# Document: a5.txt
#   Number of tokens (after stop word removal): 2254
#   Number of unique tokens (after stop word removal): 960
#
# Document: a6.txt
#   Number of tokens (after stop word removal): 1149
#   Number of unique tokens (after stop word removal): 543
#
# Document: a7.txt
#   Number of tokens (after stop word removal): 1063
#   Number of unique tokens (after stop word removal): 530
#
# Document: a8.txt
#   Number of tokens (after stop word removal): 1201
#   Number of unique tokens (after stop word removal): 590
#
# Document: a9.txt
#   Number of tokens (after stop word removal): 1028
#   Number of unique tokens (after stop word removal): 496
#
# Corpus Summary After Removing Stop Words:
#   Total tokens in corpus (after stop word removal): 15526
#   Total unique tokens in corpus (after stop word removal): 3646
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Shalritvik\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Shalritvik\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Stemming/Lemmatization

# %%
# Downloading necessary resources from nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Load the list of English stop words
stop_words = set(stopwords.words('english'))

# Initialize Porter Stemmer and WordNet Lemmatizer
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# Path to the folder containing the text files
folder_path = 'Data'

# Functions to stem and lemmatize tokens
def stem_tokens(tokens):
    return [stemmer.stem(token) for token in tokens]

def lemmatize_tokens(tokens):
    return [lemmatizer.lemmatize(token) for token in tokens]

# Function to read, tokenize, remove stop words, and apply stemming or lemmatization
def process_document(file_path, mode='stem'):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
        # Tokenize the content
        tokens = word_tokenize(content)
        # Remove stop words
        filtered_tokens = [token.lower() for token in tokens if token.lower() not in stop_words]
        # Apply stemming or lemmatization
        if mode == 'stem':
            processed_tokens = stem_tokens(filtered_tokens)
        elif mode == 'lemmatize':
            processed_tokens = lemmatize_tokens(filtered_tokens)
        return processed_tokens

# Choose mode: 'stem' for stemming, 'lemmatize' for lemmatization
mode = 'stem'  # Change to 'lemmatize' if you prefer lemmatization

# Initialize variables to store terms for the entire corpus
corpus_terms = []
corpus_unique_terms = set()

# Process each document in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.txt'):
        file_path = os.path.join(folder_path, filename)
        processed_tokens = process_document(file_path, mode=mode)
        
        # Count terms and unique terms for each document
        num_terms = len(processed_tokens)
        num_unique_terms = len(set(processed_tokens))
        print(f"Document: {filename} (Mode: {mode})")
        print(f"  Number of terms (after {mode}): {num_terms}")
        print(f"  Number of unique terms (after {mode}): {num_unique_terms}\n")
        
        # Add processed tokens to the corpus
        corpus_terms.extend(processed_tokens)
        corpus_unique_terms.update(processed_tokens)

# Summary for the entire corpus
corpus_num_terms = len(corpus_terms)
corpus_num_unique_terms = len(corpus_unique_terms)

print(f"Corpus Summary After {mode.capitalize()}:")
print(f"  Total terms in corpus (after {mode}): {corpus_num_terms}")
print(f"  Total unique terms in corpus (after {mode}): {corpus_num_unique_terms}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Shalritvik\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Shalritvik\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Shalritvik\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Document: a1.txt (Mode: stem)
#   Number of terms (after stem): 1244
#   Number of unique terms (after stem): 493
#
# Document: a10.txt (Mode: stem)
#   Number of terms (after stem): 927
#   Number of unique terms (after stem): 432
#
# Document: a2.txt (Mode: stem)
#   Number of terms (after stem): 3082
#   Number of unique terms (after stem): 985
#
# Document: a3.txt (Mode: stem)
#   Number of terms (after stem): 1382
#   Number of unique terms (after stem): 573
#
# Document: a4.txt (Mode: stem)
#   Number of terms (after stem): 2196
#   Number of unique terms (after stem): 770
#
# Document: a5.txt (Mode: stem)
#   Number of terms (after stem): 2254
#   Number of unique terms (after stem): 829
#
# Document: a6.txt (Mode: stem)
#   Number of terms (after stem): 1149
#   Number of unique terms (after stem): 498
#
# Document: a7.txt (Mode: stem)
#   Number of terms (after stem): 1063
#   Number of unique terms (after stem): 487
#
# Document: a8.txt (Mode: stem)
#   Number of terms (after stem): 1201
#   Number of unique terms (after stem): 522
#
# Document: a9.txt (Mode: stem)
#   Number of terms (after stem): 1028
#   Number of unique terms (after stem): 444
#
# Corpus Summary After Stem:
#   Total terms in corpus (after stem): 15526
#   Total unique terms in corpus (after stem): 2878

# %% [markdown]
# Compute TF-IDF

# %%
import os
from sklearn.feature_extraction.text import TfidfVectorizer

# Path to the folder containing the text files
folder_path = 'Data'

# Function to read the content of all documents
def read_documents(folder_path):
    documents = []
    filenames = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                content = file.read()
                documents.append(content)
                filenames.append(filename)
    return documents, filenames

# Read the documents
documents, filenames = read_documents(folder_path)

# Create a TfidfVectorizer instance
vectorizer = TfidfVectorizer(stop_words='english')

# Fit the vectorizer and transform the documents into TF-IDF features
tfidf_matrix = vectorizer.fit_transform(documents)

# Get the feature names (terms)
terms = vectorizer.get_feature_names_out()

# Display the TF-IDF features for each document
print("\nTF-IDF Features for Each Document:")
for i, filename in enumerate(filenames):
    print(f"\nDocument: {filename}")
    feature_index = tfidf_matrix[i, :].nonzero()[1]
    tfidf_scores = zip(feature_index, [tfidf_matrix[i, x] for x in feature_index])
    for idx, score in sorted(tfidf_scores, key=lambda x: -x[1]):
        print(f"  Term: {terms[idx]}, TF-IDF Score: {score:.4f}")
# Out:
# TF-IDF Features for Each Document:
#
# Document: a1.txt
#   Term: gyarados, TF-IDF Score: 0.8655
#   Term: pokémon, TF-IDF Score: 0.2735
#   Term: magikarp, TF-IDF Score: 0.1815
#   Term: red, TF-IDF Score: 0.0929
#   Term: flying, TF-IDF Score: 0.0623
#   Term: blue, TF-IDF Score: 0.0619
#   Term: water, TF-IDF Score: 0.0593
#   Term: game, TF-IDF Score: 0.0568
#   Term: chinese, TF-IDF Score: 0.0558
#   Term: sea, TF-IDF Score: 0.0558
#   Term: misty, TF-IDF Score: 0.0497
#   Term: team, TF-IDF Score: 0.0464
#   Term: player, TF-IDF Score: 0.0450
#   Term: type, TF-IDF Score: 0.0450
#   Term: rage, TF-IDF Score: 0.0419
#   Term: crasher, TF-IDF Score: 0.0419
#   Term: evolved, TF-IDF Score: 0.0408
#   Term: series, TF-IDF Score: 0.0396
#   Term: used, TF-IDF Score: 0.0372
#   Term: wake, TF-IDF Score: 0.0356
#   Term: lance, TF-IDF Score: 0.0356
#   Term: battle, TF-IDF Score: 0.0340
#   Term: described, TF-IDF Score: 0.0339
#   Term: shiny, TF-IDF Score: 0.0311
#   Term: dragon, TF-IDF Score: 0.0311
#   Term: later, TF-IDF Score: 0.0310
#   Term: appeared, TF-IDF Score: 0.0310
#   Term: silver, TF-IDF Score: 0.0283
#   Term: appears, TF-IDF Score: 0.0283
#   Term: known, TF-IDF Score: 0.0283
#   Term: lysandre, TF-IDF Score: 0.0279
#   Term: groudon, TF-IDF Score: 0.0279
#   Term: candies, TF-IDF Score: 0.0279
#   Term: lake, TF-IDF Score: 0.0279
#   Term: dramatic, TF-IDF Score: 0.0279
#   Term: swimming, TF-IDF Score: 0.0279
#   Term: dragons, TF-IDF Score: 0.0279
#   Term: bounce, TF-IDF Score: 0.0279
#   Term: traded, TF-IDF Score: 0.0279
#   Term: nurse, TF-IDF Score: 0.0279
#   Term: destroyed, TF-IDF Score: 0.0279
#   Term: worked, TF-IDF Score: 0.0279
#   Term: temper, TF-IDF Score: 0.0279
#   Term: generally, TF-IDF Score: 0.0277
#   Term: ign, TF-IDF Score: 0.0258
#   Term: called, TF-IDF Score: 0.0258
#   Term: games, TF-IDF Score: 0.0258
#   Term: gym, TF-IDF Score: 0.0249
#   Term: mega, TF-IDF Score: 0.0249
#   Term: evolve, TF-IDF Score: 0.0249
#   Term: featured, TF-IDF Score: 0.0249
#   Term: trainers, TF-IDF Score: 0.0249
#   Term: times, TF-IDF Score: 0.0249
#   Term: obtaining, TF-IDF Score: 0.0237
#   Term: surge, TF-IDF Score: 0.0237
#   Term: lt, TF-IDF Score: 0.0237
#   Term: 400, TF-IDF Score: 0.0237
#   Term: gaining, TF-IDF Score: 0.0237
#   Term: destructive, TF-IDF Score: 0.0237
#   Term: joy, TF-IDF Score: 0.0237
#   Term: calm, TF-IDF Score: 0.0237
#   Term: fierce, TF-IDF Score: 0.0237
#   Term: evolution, TF-IDF Score: 0.0226
#   Term: card, TF-IDF Score: 0.0225
#   Term: owns, TF-IDF Score: 0.0208
#   Term: explorers, TF-IDF Score: 0.0208
#   Term: rescue, TF-IDF Score: 0.0208
#   Term: figurines, TF-IDF Score: 0.0208
#   Term: frenzy, TF-IDF Score: 0.0208
#   Term: various, TF-IDF Score: 0.0206
#   Term: rocket, TF-IDF Score: 0.0204
#   Term: large, TF-IDF Score: 0.0204
#   Term: trading, TF-IDF Score: 0.0204
#   Term: form, TF-IDF Score: 0.0204
#   Term: author, TF-IDF Score: 0.0186
#   Term: best, TF-IDF Score: 0.0186
#   Term: white, TF-IDF Score: 0.0186
#   Term: including, TF-IDF Score: 0.0186
#   Term: species, TF-IDF Score: 0.0186
#   Term: wrote, TF-IDF Score: 0.0185
#   Term: yellow, TF-IDF Score: 0.0185
#   Term: moves, TF-IDF Score: 0.0185
#   Term: plush, TF-IDF Score: 0.0185
#   Term: owned, TF-IDF Score: 0.0185
#   Term: japanese, TF-IDF Score: 0.0170
#   Term: green, TF-IDF Score: 0.0170
#   Term: leader, TF-IDF Score: 0.0166
#   Term: returns, TF-IDF Score: 0.0166
#   Term: ownership, TF-IDF Score: 0.0166
#   Term: city, TF-IDF Score: 0.0166
#   Term: learn, TF-IDF Score: 0.0166
#   Term: powerful, TF-IDF Score: 0.0166
#   Term: toys, TF-IDF Score: 0.0166
#   Term: forms, TF-IDF Score: 0.0166
#   Term: positive, TF-IDF Score: 0.0166
#   Term: appear, TF-IDF Score: 0.0166
#   Term: appearances, TF-IDF Score: 0.0155
#   Term: appearance, TF-IDF Score: 0.0155
#   Term: generation, TF-IDF Score: 0.0155
#   Term: reception, TF-IDF Score: 0.0155
#   Term: anime, TF-IDF Score: 0.0155
#   Term: merchandise, TF-IDF Score: 0.0155
#   Term: video, TF-IDF Score: 0.0155
#   Term: crystal, TF-IDF Score: 0.0150
#   Term: experience, TF-IDF Score: 0.0150
#   Term: originally, TF-IDF Score: 0.0150
#   Term: worthiness, TF-IDF Score: 0.0140
#   Term: difficulty, TF-IDF Score: 0.0140
#   Term: iteration, TF-IDF Score: 0.0140
#   Term: laughing, TF-IDF Score: 0.0140
#   Term: toted, TF-IDF Score: 0.0140
#   Term: tribulations, TF-IDF Score: 0.0140
#   Term: trials, TF-IDF Score: 0.0140
#   Term: epitomizes, TF-IDF Score: 0.0140
#   Term: sam, TF-IDF Score: 0.0140
#   Term: 11th, TF-IDF Score: 0.0140
#   Term: tracy, TF-IDF Score: 0.0140
#   Term: balls, TF-IDF Score: 0.0140
#   Term: pester, TF-IDF Score: 0.0140
#   Term: morphed, TF-IDF Score: 0.0140
#   Term: biggest, TF-IDF Score: 0.0140
#   Term: possibly, TF-IDF Score: 0.0140
#   Term: valuable, TF-IDF Score: 0.0140
#   Term: predecessors, TF-IDF Score: 0.0140
#   Term: dismay, TF-IDF Score: 0.0140
#   Term: similarly, TF-IDF Score: 0.0140
#   Term: loredane, TF-IDF Score: 0.0140
#   Term: snout, TF-IDF Score: 0.0140
#   Term: blunted, TF-IDF Score: 0.0140
#   Term: barbels, TF-IDF Score: 0.0140
#   Term: catfish, TF-IDF Score: 0.0140
#   Term: scaled, TF-IDF Score: 0.0140
#   Term: adds, TF-IDF Score: 0.0140
#   Term: asiatic, TF-IDF Score: 0.0140
#   Term: dekirk, TF-IDF Score: 0.0140
#   Term: snake, TF-IDF Score: 0.0140
#   Term: mythological, TF-IDF Score: 0.0140
#   Term: gamers, TF-IDF Score: 0.0140
#   Term: macho, TF-IDF Score: 0.0140
#   Term: leeper, TF-IDF Score: 0.0140
#   Term: powerhouse, TF-IDF Score: 0.0140
#   Term: meyer, TF-IDF Score: 0.0140
#   Term: mix, TF-IDF Score: 0.0140
#   Term: john, TF-IDF Score: 0.0140
#   Term: weird, TF-IDF Score: 0.0140
#   Term: week, TF-IDF Score: 0.0140
#   Term: ultimate, TF-IDF Score: 0.0140
#   Term: crazy, TF-IDF Score: 0.0140
#   Term: disturb, TF-IDF Score: 0.0140
#   Term: faceoff, TF-IDF Score: 0.0140
#   Term: trades, TF-IDF Score: 0.0140
#   Term: borrows, TF-IDF Score: 0.0140
#   Term: krabby, TF-IDF Score: 0.0140
#   Term: exchange, TF-IDF Score: 0.0140
#   Term: recaught, TF-IDF Score: 0.0140
#   Term: enraged, TF-IDF Score: 0.0140
#   Term: splashes, TF-IDF Score: 0.0140
#   Term: debuts, TF-IDF Score: 0.0140
#   Term: union, TF-IDF Score: 0.0140
#   Term: perfect, TF-IDF Score: 0.0140
#   Term: forming, TF-IDF Score: 0.0140
#   Term: pyroar, TF-IDF Score: 0.0140
#   Term: usage, TF-IDF Score: 0.0140
#   Term: kyogre, TF-IDF Score: 0.0140
#   Term: feuding, TF-IDF Score: 0.0140
#   Term: legends, TF-IDF Score: 0.0140
#   Term: scuffle, TF-IDF Score: 0.0140
#   Term: innocence, TF-IDF Score: 0.0140
#   Term: bout, TF-IDF Score: 0.0140
#   Term: talkin, TF-IDF Score: 0.0140
#   Term: add, TF-IDF Score: 0.0140
#   Term: traumatic, TF-IDF Score: 0.0140
#   Term: dislikes, TF-IDF Score: 0.0140
#   Term: fearfully, TF-IDF Score: 0.0140
#   Term: frustration, TF-IDF Score: 0.0140
#   Term: kicked, TF-IDF Score: 0.0140
#   Term: shipwreck, TF-IDF Score: 0.0140
#   Term: river, TF-IDF Score: 0.0140
#   Term: spectating, TF-IDF Score: 0.0140
#   Term: background, TF-IDF Score: 0.0140
#   Term: arenas, TF-IDF Score: 0.0140
#   Term: switch, TF-IDF Score: 0.0140
#   Term: deluxe, TF-IDF Score: 0.0140
#   Term: dash, TF-IDF Score: 0.0140
#   Term: host, TF-IDF Score: 0.0140
#   Term: absence, TF-IDF Score: 0.0140
#   Term: empoleon, TF-IDF Score: 0.0140
#   Term: zone, TF-IDF Score: 0.0140
#   Term: beach, TF-IDF Score: 0.0140
#   Term: halted, TF-IDF Score: 0.0140
#   Term: phione, TF-IDF Score: 0.0140
#   Term: miracle, TF-IDF Score: 0.0140
#   Term: breaker, TF-IDF Score: 0.0140
#   Term: mold, TF-IDF Score: 0.0140
#   Term: lucy, TF-IDF Score: 0.0140
#   Term: pike, TF-IDF Score: 0.0140
#   Term: wallace, TF-IDF Score: 0.0140
#   Term: quest, TF-IDF Score: 0.0140
#   Term: mahogany, TF-IDF Score: 0.0140
#   Term: hideout, TF-IDF Score: 0.0140
#   Term: triggers, TF-IDF Score: 0.0140
#   Term: incident, TF-IDF Score: 0.0140
#   Term: come, TF-IDF Score: 0.0140
#   Term: rod, TF-IDF Score: 0.0140
#   Term: fishing, TF-IDF Score: 0.0140
#   Term: uncommonly, TF-IDF Score: 0.0140
#   Term: oceans, TF-IDF Score: 0.0140
#   Term: seas, TF-IDF Score: 0.0140
#   Term: ponds, TF-IDF Score: 0.0140
#   Term: lakes, TF-IDF Score: 0.0140
#   Term: bodies, TF-IDF Score: 0.0140
#   Term: conflict, TF-IDF Score: 0.0140
#   Term: undergoes, TF-IDF Score: 0.0140
#   Term: structural, TF-IDF Score: 0.0140
#   Term: nature, TF-IDF Score: 0.0140
#   Term: tendencies, TF-IDF Score: 0.0140
#   Term: wanton, TF-IDF Score: 0.0140
#   Term: gaping, TF-IDF Score: 0.0140
#   Term: fins, TF-IDF Score: 0.0140
#   Term: pale, TF-IDF Score: 0.0140
#   Term: underbelly, TF-IDF Score: 0.0140
#   Term: snakelike, TF-IDF Score: 0.0140
#   Term: upstream, TF-IDF Score: 0.0140
#   Term: carp, TF-IDF Score: 0.0140
#   Term: tradition, TF-IDF Score: 0.0140
#   Term: mythology, TF-IDF Score: 0.0140
#   Term: serpent, TF-IDF Score: 0.0140
#   Term: kraken, TF-IDF Score: 0.0140
#   Term: skulk, TF-IDF Score: 0.0140
#   Term: skulkraken, TF-IDF Score: 0.0140
#   Term: beta, TF-IDF Score: 0.0140
#   Term: iv, TF-IDF Score: 0.0140
#   Term: hurricane, TF-IDF Score: 0.0140
#   Term: exceptions, TF-IDF Score: 0.0140
#   Term: destruction, TF-IDF Score: 0.0140
#   Term: reputation, TF-IDF Score: 0.0140
#   Term: atrocious, TF-IDF Score: 0.0140
#   Term: ishizuka, TF-IDF Score: 0.0140
#   Term: unshō, TF-IDF Score: 0.0140
#   Term: gyaradosu, TF-IDF Score: 0.0140
#   Term: ギャラドス, TF-IDF Score: 0.0140
#   Term: attack, TF-IDF Score: 0.0136
#   Term: able, TF-IDF Score: 0.0136
#   Term: snap, TF-IDF Score: 0.0136
#   Term: pearl, TF-IDF Score: 0.0136
#   Term: diamond, TF-IDF Score: 0.0136
#   Term: evolves, TF-IDF Score: 0.0136
#   Term: seen, TF-IDF Score: 0.0136
#   Term: black, TF-IDF Score: 0.0124
#   Term: editor, TF-IDF Score: 0.0124
#   Term: gamesradar, TF-IDF Score: 0.0124
#   Term: pikachu, TF-IDF Score: 0.0124
#   Term: dungeon, TF-IDF Score: 0.0124
#   Term: mystery, TF-IDF Score: 0.0124
#   Term: outside, TF-IDF Score: 0.0124
#   Term: different, TF-IDF Score: 0.0124
#   Term: subsequent, TF-IDF Score: 0.0124
#   Term: newest, TF-IDF Score: 0.0119
#   Term: badass, TF-IDF Score: 0.0119
#   Term: sure, TF-IDF Score: 0.0119
#   Term: lamest, TF-IDF Score: 0.0119
#   Term: training, TF-IDF Score: 0.0119
#   Term: iconic, TF-IDF Score: 0.0119
#   Term: voted, TF-IDF Score: 0.0119
#   Term: experiences, TF-IDF Score: 0.0119
#   Term: growth, TF-IDF Score: 0.0119
#   Term: low, TF-IDF Score: 0.0119
#   Term: ruined, TF-IDF Score: 0.0119
#   Term: commenting, TF-IDF Score: 0.0119
#   Term: somewhat, TF-IDF Score: 0.0119
#   Term: sapphire, TF-IDF Score: 0.0119
#   Term: gate, TF-IDF Score: 0.0119
#   Term: myth, TF-IDF Score: 0.0119
#   Term: comparing, TF-IDF Score: 0.0119
#   Term: encountered, TF-IDF Score: 0.0119
#   Term: justin, TF-IDF Score: 0.0119
#   Term: gamespy, TF-IDF Score: 0.0119
#   Term: classic, TF-IDF Score: 0.0119
#   Term: wired, TF-IDF Score: 0.0119
#   Term: discussing, TF-IDF Score: 0.0119
#   Term: useless, TF-IDF Score: 0.0119
#   Term: discovered, TF-IDF Score: 0.0119
#   Term: remained, TF-IDF Score: 0.0119
#   Term: frozen, TF-IDF Score: 0.0119
#   Term: masked, TF-IDF Score: 0.0119
#   Term: goldenrod, TF-IDF Score: 0.0119
#   Term: group, TF-IDF Score: 0.0119
#   Term: prior, TF-IDF Score: 0.0119
#   Term: mt, TF-IDF Score: 0.0119
#   Term: killed, TF-IDF Score: 0.0119
#   Term: mastermind, TF-IDF Score: 0.0119
#   Term: apart, TF-IDF Score: 0.0119
#   Term: coming, TF-IDF Score: 0.0119
#   Term: captured, TF-IDF Score: 0.0119
#   Term: rampage, TF-IDF Score: 0.0119
#   Term: focused, TF-IDF Score: 0.0119
#   Term: cerulean, TF-IDF Score: 0.0119
#   Term: fear, TF-IDF Score: 0.0119
#   Term: manages, TF-IDF Score: 0.0119
#   Term: requires, TF-IDF Score: 0.0119
#   Term: difficult, TF-IDF Score: 0.0119
#   Term: aqua, TF-IDF Score: 0.0119
#   Term: tries, TF-IDF Score: 0.0119
#   Term: cyrus, TF-IDF Score: 0.0119
#   Term: queen, TF-IDF Score: 0.0119
#   Term: clair, TF-IDF Score: 0.0119
#   Term: sets, TF-IDF Score: 0.0119
#   Term: mentioned, TF-IDF Score: 0.0119
#   Term: chance, TF-IDF Score: 0.0119
#   Term: ground, TF-IDF Score: 0.0119
#   Term: cities, TF-IDF Score: 0.0119
#   Term: entire, TF-IDF Score: 0.0119
#   Term: burning, TF-IDF Score: 0.0119
#   Term: violent, TF-IDF Score: 0.0119
#   Term: month, TF-IDF Score: 0.0119
#   Term: skull, TF-IDF Score: 0.0119
#   Term: onwards, TF-IDF Score: 0.0119
#   Term: characters, TF-IDF Score: 0.0113
#   Term: received, TF-IDF Score: 0.0113
#   Term: freak, TF-IDF Score: 0.0113
#   Term: traditional, TF-IDF Score: 0.0104
#   Term: continues, TF-IDF Score: 0.0104
#   Term: fun, TF-IDF Score: 0.0104
#   Term: says, TF-IDF Score: 0.0104
#   Term: fourth, TF-IDF Score: 0.0104
#   Term: throw, TF-IDF Score: 0.0104
#   Term: giving, TF-IDF Score: 0.0104
#   Term: expressed, TF-IDF Score: 0.0104
#   Term: chick, TF-IDF Score: 0.0104
#   Term: year, TF-IDF Score: 0.0104
#   Term: lipperini, TF-IDF Score: 0.0104
#   Term: inspired, TF-IDF Score: 0.0104
#   Term: image, TF-IDF Score: 0.0104
#   Term: returned, TF-IDF Score: 0.0104
#   Term: free, TF-IDF Score: 0.0104
#   Term: man, TF-IDF Score: 0.0104
#   Term: caught, TF-IDF Score: 0.0104
#   Term: went, TF-IDF Score: 0.0104
#   Term: radio, TF-IDF Score: 0.0104
#   Term: saga, TF-IDF Score: 0.0104
#   Term: entei, TF-IDF Score: 0.0104
#   Term: 13, TF-IDF Score: 0.0104
#   Term: temporarily, TF-IDF Score: 0.0104
#   Term: chapter, TF-IDF Score: 0.0104
#   Term: flare, TF-IDF Score: 0.0104
#   Term: dreams, TF-IDF Score: 0.0104
#   Term: stop, TF-IDF Score: 0.0104
#   Term: fighter, TF-IDF Score: 0.0104
#   Term: festival, TF-IDF Score: 0.0104
#   Term: mini, TF-IDF Score: 0.0104
#   Term: darkness, TF-IDF Score: 0.0104
#   Term: gains, TF-IDF Score: 0.0104
#   Term: dark, TF-IDF Score: 0.0104
#   Term: gain, TF-IDF Score: 0.0104
#   Term: defeats, TF-IDF Score: 0.0104
#   Term: brain, TF-IDF Score: 0.0104
#   Term: largely, TF-IDF Score: 0.0104
#   Term: ancient, TF-IDF Score: 0.0104
#   Term: multiple, TF-IDF Score: 0.0104
#   Term: world, TF-IDF Score: 0.0104
#   Term: ash, TF-IDF Score: 0.0103
#   Term: make, TF-IDF Score: 0.0103
#   Term: character, TF-IDF Score: 0.0103
#   Term: manga, TF-IDF Score: 0.0103
#   Term: adventures, TF-IDF Score: 0.0103
#   Term: adaptations, TF-IDF Score: 0.0103
#   Term: printed, TF-IDF Score: 0.0103
#   Term: sugimori, TF-IDF Score: 0.0103
#   Term: ken, TF-IDF Score: 0.0103
#   Term: franchise, TF-IDF Score: 0.0103
#   Term: nintendo, TF-IDF Score: 0.0103
#   Term: readers, TF-IDF Score: 0.0092
#   Term: better, TF-IDF Score: 0.0092
#   Term: commented, TF-IDF Score: 0.0092
#   Term: special, TF-IDF Score: 0.0092
#   Term: day, TF-IDF Score: 0.0092
#   Term: resembling, TF-IDF Score: 0.0092
#   Term: choice, TF-IDF Score: 0.0092
#   Term: example, TF-IDF Score: 0.0092
#   Term: tower, TF-IDF Score: 0.0092
#   Term: volume, TF-IDF Score: 0.0092
#   Term: travel, TF-IDF Score: 0.0092
#   Term: charizard, TF-IDF Score: 0.0092
#   Term: trainer, TF-IDF Score: 0.0092
#   Term: choose, TF-IDF Score: 0.0092
#   Term: pokkén, TF-IDF Score: 0.0092
#   Term: obtain, TF-IDF Score: 0.0092
#   Term: poképark, TF-IDF Score: 0.0092
#   Term: attempts, TF-IDF Score: 0.0092
#   Term: beginning, TF-IDF Score: 0.0092
#   Term: town, TF-IDF Score: 0.0092
#   Term: elite, TF-IDF Score: 0.0092
#   Term: catch, TF-IDF Score: 0.0092
#   Term: usually, TF-IDF Score: 0.0092
#   Term: changes, TF-IDF Score: 0.0092
#   Term: attributed, TF-IDF Score: 0.0092
#   Term: mouth, TF-IDF Score: 0.0092
#   Term: concept, TF-IDF Score: 0.0092
#   Term: release, TF-IDF Score: 0.0092
#   Term: result, TF-IDF Score: 0.0092
#   Term: causing, TF-IDF Score: 0.0092
#   Term: favorite, TF-IDF Score: 0.0083
#   Term: citing, TF-IDF Score: 0.0083
#   Term: describing, TF-IDF Score: 0.0083
#   Term: change, TF-IDF Score: 0.0083
#   Term: tale, TF-IDF Score: 0.0083
#   Term: revealed, TF-IDF Score: 0.0083
#   Term: attacks, TF-IDF Score: 0.0083
#   Term: tournament, TF-IDF Score: 0.0083
#   Term: considered, TF-IDF Score: 0.0083
#   Term: control, TF-IDF Score: 0.0083
#   Term: notable, TF-IDF Score: 0.0083
#   Term: sequel, TF-IDF Score: 0.0083
#   Term: evolving, TF-IDF Score: 0.0083
#   Term: combination, TF-IDF Score: 0.0083
#   Term: 151, TF-IDF Score: 0.0083
#   Term: introduced, TF-IDF Score: 0.0083
#   Term: west, TF-IDF Score: 0.0075
#   Term: new, TF-IDF Score: 0.0075
#   Term: electric, TF-IDF Score: 0.0075
#   Term: male, TF-IDF Score: 0.0075
#   Term: james, TF-IDF Score: 0.0075
#   Term: wii, TF-IDF Score: 0.0075
#   Term: makes, TF-IDF Score: 0.0075
#   Term: heartgold, TF-IDF Score: 0.0075
#   Term: live, TF-IDF Score: 0.0075
#   Term: human, TF-IDF Score: 0.0075
#   Term: final, TF-IDF Score: 0.0075
#   Term: finalized, TF-IDF Score: 0.0075
#   Term: conceived, TF-IDF Score: 0.0075
#   Term: designs, TF-IDF Score: 0.0075
#   Term: pokemon, TF-IDF Score: 0.0075
#   Term: listed, TF-IDF Score: 0.0068
#   Term: end, TF-IDF Score: 0.0068
#   Term: playable, TF-IDF Score: 0.0068
#   Term: shown, TF-IDF Score: 0.0068
#   Term: version, TF-IDF Score: 0.0068
#   Term: ranger, TF-IDF Score: 0.0068
#   Term: ability, TF-IDF Score: 0.0068
#   Term: soulsilver, TF-IDF Score: 0.0068
#   Term: remakes, TF-IDF Score: 0.0068
#   Term: super, TF-IDF Score: 0.0068
#   Term: said, TF-IDF Score: 0.0068
#   Term: based, TF-IDF Score: 0.0068
#   Term: similar, TF-IDF Score: 0.0068
#   Term: relatable, TF-IDF Score: 0.0068
#   Term: western, TF-IDF Score: 0.0068
#   Term: translating, TF-IDF Score: 0.0068
#   Term: descriptive, TF-IDF Score: 0.0068
#   Term: clever, TF-IDF Score: 0.0068
#   Term: decided, TF-IDF Score: 0.0068
#   Term: localized, TF-IDF Score: 0.0068
#   Term: appearing, TF-IDF Score: 0.0068
#   Term: named, TF-IDF Score: 0.0062
#   Term: adventure, TF-IDF Score: 0.0062
#   Term: time, TF-IDF Score: 0.0062
#   Term: original, TF-IDF Score: 0.0062
#   Term: means, TF-IDF Score: 0.0062
#   Term: names, TF-IDF Score: 0.0062
#   Term: monsters, TF-IDF Score: 0.0062
#   Term: pocket, TF-IDF Score: 0.0062
#   Term: development, TF-IDF Score: 0.0062
#   Term: characteristics, TF-IDF Score: 0.0062
#   Term: voiced, TF-IDF Score: 0.0062
#   Term: titles, TF-IDF Score: 0.0062
#   Term: spinoff, TF-IDF Score: 0.0062
#   Term: created, TF-IDF Score: 0.0062
#   Term: leafgreen, TF-IDF Score: 0.0057
#   Term: firered, TF-IDF Score: 0.0057
#   Term: like, TF-IDF Score: 0.0057
#   Term: main, TF-IDF Score: 0.0057
#   Term: gold, TF-IDF Score: 0.0057
#   Term: body, TF-IDF Score: 0.0057
#   Term: american, TF-IDF Score: 0.0057
#   Term: audiences, TF-IDF Score: 0.0057
#   Term: features, TF-IDF Score: 0.0057
#   Term: related, TF-IDF Score: 0.0057
#   Term: japan, TF-IDF Score: 0.0057
#   Term: design, TF-IDF Score: 0.0057
#   Term: english, TF-IDF Score: 0.0057
#   Term: sequels, TF-IDF Score: 0.0057
#   Term: bulbapedia, TF-IDF Score: 0.0052
#   Term: links, TF-IDF Score: 0.0052
#   Term: external, TF-IDF Score: 0.0052
#   Term: references, TF-IDF Score: 0.0052
#   Term: children, TF-IDF Score: 0.0052
#   Term: media, TF-IDF Score: 0.0052
#   Term: animated, TF-IDF Score: 0.0052
#
# Document: a10.txt
#   Term: snorlax, TF-IDF Score: 0.8408
#   Term: pokémon, TF-IDF Score: 0.2519
#   Term: red, TF-IDF Score: 0.0731
#   Term: sleeping, TF-IDF Score: 0.0727
#   Term: lax, TF-IDF Score: 0.0659
#   Term: roadblock, TF-IDF Score: 0.0659
#   Term: munchlax, TF-IDF Score: 0.0659
#   Term: called, TF-IDF Score: 0.0650
#   Term: character, TF-IDF Score: 0.0569
#   Term: games, TF-IDF Score: 0.0569
#   Term: wake, TF-IDF Score: 0.0561
#   Term: powerful, TF-IDF Score: 0.0522
#   Term: ash, TF-IDF Score: 0.0488
#   Term: later, TF-IDF Score: 0.0488
#   Term: poké, TF-IDF Score: 0.0472
#   Term: player, TF-IDF Score: 0.0472
#   Term: pokemon, TF-IDF Score: 0.0472
#   Term: known, TF-IDF Score: 0.0445
#   Term: slam, TF-IDF Score: 0.0440
#   Term: camphrier, TF-IDF Score: 0.0440
#   Term: flute, TF-IDF Score: 0.0440
#   Term: food, TF-IDF Score: 0.0440
#   Term: silly, TF-IDF Score: 0.0440
#   Term: downright, TF-IDF Score: 0.0440
#   Term: heaviest, TF-IDF Score: 0.0440
#   Term: pounds, TF-IDF Score: 0.0440
#   Term: 000, TF-IDF Score: 0.0440
#   Term: weigh, TF-IDF Score: 0.0440
#   Term: kabigon, TF-IDF Score: 0.0440
#   Term: play, TF-IDF Score: 0.0436
#   Term: calling, TF-IDF Score: 0.0436
#   Term: town, TF-IDF Score: 0.0436
#   Term: ign, TF-IDF Score: 0.0406
#   Term: children, TF-IDF Score: 0.0406
#   Term: time, TF-IDF Score: 0.0390
#   Term: used, TF-IDF Score: 0.0390
#   Term: obtained, TF-IDF Score: 0.0374
#   Term: belly, TF-IDF Score: 0.0374
#   Term: gamespy, TF-IDF Score: 0.0374
#   Term: certain, TF-IDF Score: 0.0354
#   Term: cat, TF-IDF Score: 0.0327
#   Term: gary, TF-IDF Score: 0.0327
#   Term: radio, TF-IDF Score: 0.0327
#   Term: game, TF-IDF Score: 0.0325
#   Term: large, TF-IDF Score: 0.0321
#   Term: best, TF-IDF Score: 0.0293
#   Term: editor, TF-IDF Score: 0.0293
#   Term: pikachu, TF-IDF Score: 0.0293
#   Term: voiced, TF-IDF Score: 0.0293
#   Term: species, TF-IDF Score: 0.0293
#   Term: defeating, TF-IDF Score: 0.0291
#   Term: high, TF-IDF Score: 0.0291
#   Term: head, TF-IDF Score: 0.0291
#   Term: ketchum, TF-IDF Score: 0.0291
#   Term: poképark, TF-IDF Score: 0.0291
#   Term: main, TF-IDF Score: 0.0267
#   Term: body, TF-IDF Score: 0.0267
#   Term: series, TF-IDF Score: 0.0267
#   Term: pre, TF-IDF Score: 0.0261
#   Term: compared, TF-IDF Score: 0.0261
#   Term: feet, TF-IDF Score: 0.0261
#   Term: considered, TF-IDF Score: 0.0261
#   Term: blue, TF-IDF Score: 0.0244
#   Term: anime, TF-IDF Score: 0.0244
#   Term: media, TF-IDF Score: 0.0244
#   Term: various, TF-IDF Score: 0.0244
#   Term: video, TF-IDF Score: 0.0244
#   Term: using, TF-IDF Score: 0.0236
#   Term: smash, TF-IDF Score: 0.0236
#   Term: designs, TF-IDF Score: 0.0236
#   Term: fanmade, TF-IDF Score: 0.0220
#   Term: commonly, TF-IDF Score: 0.0220
#   Term: surprisingly, TF-IDF Score: 0.0220
#   Term: hell, TF-IDF Score: 0.0220
#   Term: lazy, TF-IDF Score: 0.0220
#   Term: watson, TF-IDF Score: 0.0220
#   Term: elijah, TF-IDF Score: 0.0220
#   Term: 28th, TF-IDF Score: 0.0220
#   Term: dwarfs, TF-IDF Score: 0.0220
#   Term: seven, TF-IDF Score: 0.0220
#   Term: snow, TF-IDF Score: 0.0220
#   Term: sleepy, TF-IDF Score: 0.0220
#   Term: barbo, TF-IDF Score: 0.0220
#   Term: maria, TF-IDF Score: 0.0220
#   Term: laziest, TF-IDF Score: 0.0220
#   Term: symbolizing, TF-IDF Score: 0.0220
#   Term: regression, TF-IDF Score: 0.0220
#   Term: interpret, TF-IDF Score: 0.0220
#   Term: sic, TF-IDF Score: 0.0220
#   Term: effective, TF-IDF Score: 0.0220
#   Term: tank, TF-IDF Score: 0.0220
#   Term: tauros, TF-IDF Score: 0.0220
#   Term: isn, TF-IDF Score: 0.0220
#   Term: evolver, TF-IDF Score: 0.0220
#   Term: immobility, TF-IDF Score: 0.0220
#   Term: peculiar, TF-IDF Score: 0.0220
#   Term: today, TF-IDF Score: 0.0220
#   Term: disorder, TF-IDF Score: 0.0220
#   Term: glandular, TF-IDF Score: 0.0220
#   Term: physically, TF-IDF Score: 0.0220
#   Term: extensive, TF-IDF Score: 0.0220
#   Term: smell, TF-IDF Score: 0.0220
#   Term: driven, TF-IDF Score: 0.0220
#   Term: gluttonous, TF-IDF Score: 0.0220
#   Term: bicycle, TF-IDF Score: 0.0220
#   Term: road, TF-IDF Score: 0.0220
#   Term: nicknames, TF-IDF Score: 0.0220
#   Term: flattening, TF-IDF Score: 0.0220
#   Term: punch, TF-IDF Score: 0.0220
#   Term: hariyama, TF-IDF Score: 0.0220
#   Term: wheel, TF-IDF Score: 0.0220
#   Term: greta, TF-IDF Score: 0.0220
#   Term: guts, TF-IDF Score: 0.0220
#   Term: earn, TF-IDF Score: 0.0220
#   Term: recently, TF-IDF Score: 0.0220
#   Term: houndoom, TF-IDF Score: 0.0220
#   Term: hypno, TF-IDF Score: 0.0220
#   Term: steelix, TF-IDF Score: 0.0220
#   Term: following, TF-IDF Score: 0.0220
#   Term: fought, TF-IDF Score: 0.0220
#   Term: scizor, TF-IDF Score: 0.0220
#   Term: arcanine, TF-IDF Score: 0.0220
#   Term: nidoqueen, TF-IDF Score: 0.0220
#   Term: kingdra, TF-IDF Score: 0.0220
#   Term: masters, TF-IDF Score: 0.0220
#   Term: sumo, TF-IDF Score: 0.0220
#   Term: opting, TF-IDF Score: 0.0220
#   Term: sporadically, TF-IDF Score: 0.0220
#   Term: grapefruit, TF-IDF Score: 0.0220
#   Term: grapefruits, TF-IDF Score: 0.0220
#   Term: eating, TF-IDF Score: 0.0220
#   Term: snack, TF-IDF Score: 0.0220
#   Term: 41, TF-IDF Score: 0.0220
#   Term: supporting, TF-IDF Score: 0.0220
#   Term: occurs, TF-IDF Score: 0.0220
#   Term: hits, TF-IDF Score: 0.0220
#   Term: whomever, TF-IDF Score: 0.0220
#   Term: slams, TF-IDF Score: 0.0220
#   Term: jumps, TF-IDF Score: 0.0220
#   Term: browser, TF-IDF Score: 0.0220
#   Term: completes, TF-IDF Score: 0.0220
#   Term: remains, TF-IDF Score: 0.0220
#   Term: cutting, TF-IDF Score: 0.0220
#   Term: effectively, TF-IDF Score: 0.0220
#   Term: scoring, TF-IDF Score: 0.0220
#   Term: music, TF-IDF Score: 0.0220
#   Term: dances, TF-IDF Score: 0.0220
#   Term: stands, TF-IDF Score: 0.0220
#   Term: pokéflute, TF-IDF Score: 0.0220
#   Term: pancake, TF-IDF Score: 0.0220
#   Term: pulverizing, TF-IDF Score: 0.0220
#   Term: castle, TF-IDF Score: 0.0220
#   Term: shabboneau, TF-IDF Score: 0.0220
#   Term: locals, TF-IDF Score: 0.0220
#   Term: bridge, TF-IDF Score: 0.0220
#   Term: wandering, TF-IDF Score: 0.0220
#   Term: wasn, TF-IDF Score: 0.0220
#   Term: gale, TF-IDF Score: 0.0220
#   Term: xd, TF-IDF Score: 0.0220
#   Term: holding, TF-IDF Score: 0.0220
#   Term: breeding, TF-IDF Score: 0.0220
#   Term: bloated, TF-IDF Score: 0.0220
#   Term: docile, TF-IDF Score: 0.0220
#   Term: dissolve, TF-IDF Score: 0.0220
#   Term: juices, TF-IDF Score: 0.0220
#   Term: digestive, TF-IDF Score: 0.0220
#   Term: rotten, TF-IDF Score: 0.0220
#   Term: moldy, TF-IDF Score: 0.0220
#   Term: devour, TF-IDF Score: 0.0220
#   Term: appetite, TF-IDF Score: 0.0220
#   Term: enormous, TF-IDF Score: 0.0220
#   Term: grab, TF-IDF Score: 0.0220
#   Term: chooses, TF-IDF Score: 0.0220
#   Term: balance, TF-IDF Score: 0.0220
#   Term: assisting, TF-IDF Score: 0.0220
#   Term: jaw, TF-IDF Score: 0.0220
#   Term: lower, TF-IDF Score: 0.0220
#   Term: sticking, TF-IDF Score: 0.0220
#   Term: teeth, TF-IDF Score: 0.0220
#   Term: relax, TF-IDF Score: 0.0220
#   Term: snore, TF-IDF Score: 0.0220
#   Term: spells, TF-IDF Score: 0.0220
#   Term: basing, TF-IDF Score: 0.0220
#   Term: conception, TF-IDF Score: 0.0220
#   Term: stuart, TF-IDF Score: 0.0220
#   Term: haigney, TF-IDF Score: 0.0220
#   Term: michael, TF-IDF Score: 0.0220
#   Term: respectively, TF-IDF Score: 0.0220
#   Term: pichu, TF-IDF Score: 0.0220
#   Term: shorts, TF-IDF Score: 0.0220
#   Term: ogata, TF-IDF Score: 0.0220
#   Term: mitsuru, TF-IDF Score: 0.0220
#   Term: takagi, TF-IDF Score: 0.0220
#   Term: hitoshi, TF-IDF Score: 0.0220
#   Term: konishi, TF-IDF Score: 0.0220
#   Term: katsuyuki, TF-IDF Score: 0.0220
#   Term: カビゴン, TF-IDF Score: 0.0220
#   Term: use, TF-IDF Score: 0.0214
#   Term: bros, TF-IDF Score: 0.0214
#   Term: ranger, TF-IDF Score: 0.0214
#   Term: remakes, TF-IDF Score: 0.0214
#   Term: super, TF-IDF Score: 0.0214
#   Term: said, TF-IDF Score: 0.0214
#   Term: seen, TF-IDF Score: 0.0214
#   Term: author, TF-IDF Score: 0.0195
#   Term: adventure, TF-IDF Score: 0.0195
#   Term: characteristics, TF-IDF Score: 0.0195
#   Term: awesome, TF-IDF Score: 0.0187
#   Term: 50, TF-IDF Score: 0.0187
#   Term: lucas, TF-IDF Score: 0.0187
#   Term: loredana, TF-IDF Score: 0.0187
#   Term: state, TF-IDF Score: 0.0187
#   Term: icon, TF-IDF Score: 0.0187
#   Term: fan, TF-IDF Score: 0.0187
#   Term: types, TF-IDF Score: 0.0187
#   Term: single, TF-IDF Score: 0.0187
#   Term: honey, TF-IDF Score: 0.0187
#   Term: race, TF-IDF Score: 0.0187
#   Term: blocking, TF-IDF Score: 0.0187
#   Term: catches, TF-IDF Score: 0.0187
#   Term: medicham, TF-IDF Score: 0.0187
#   Term: symbol, TF-IDF Score: 0.0187
#   Term: fell, TF-IDF Score: 0.0187
#   Term: harrison, TF-IDF Score: 0.0187
#   Term: rematch, TF-IDF Score: 0.0187
#   Term: ring, TF-IDF Score: 0.0187
#   Term: constantly, TF-IDF Score: 0.0187
#   Term: traveling, TF-IDF Score: 0.0187
#   Term: roles, TF-IDF Score: 0.0187
#   Term: asleep, TF-IDF Score: 0.0187
#   Term: lying, TF-IDF Score: 0.0187
#   Term: float, TF-IDF Score: 0.0187
#   Term: picture, TF-IDF Score: 0.0187
#   Term: mentions, TF-IDF Score: 0.0187
#   Term: acts, TF-IDF Score: 0.0187
#   Term: poison, TF-IDF Score: 0.0187
#   Term: kind, TF-IDF Score: 0.0187
#   Term: stomach, TF-IDF Score: 0.0187
#   Term: eat, TF-IDF Score: 0.0187
#   Term: pointed, TF-IDF Score: 0.0187
#   Term: teal, TF-IDF Score: 0.0187
#   Term: rest, TF-IDF Score: 0.0187
#   Term: iii, TF-IDF Score: 0.0187
#   Term: eric, TF-IDF Score: 0.0187
#   Term: training, TF-IDF Score: 0.0187
#   Term: clair, TF-IDF Score: 0.0187
#   Term: evolution, TF-IDF Score: 0.0178
#   Term: american, TF-IDF Score: 0.0178
#   Term: japan, TF-IDF Score: 0.0178
#   Term: described, TF-IDF Score: 0.0178
#   Term: received, TF-IDF Score: 0.0178
#   Term: appears, TF-IDF Score: 0.0178
#   Term: japanese, TF-IDF Score: 0.0178
#   Term: freak, TF-IDF Score: 0.0178
#   Term: saying, TF-IDF Score: 0.0163
#   Term: complex, TF-IDF Score: 0.0163
#   Term: recognizable, TF-IDF Score: 0.0163
#   Term: aspects, TF-IDF Score: 0.0163
#   Term: relate, TF-IDF Score: 0.0163
#   Term: worlds, TF-IDF Score: 0.0163
#   Term: believe, TF-IDF Score: 0.0163
#   Term: greatest, TF-IDF Score: 0.0163
#   Term: decides, TF-IDF Score: 0.0163
#   Term: strength, TF-IDF Score: 0.0163
#   Term: noting, TF-IDF Score: 0.0163
#   Term: usa, TF-IDF Score: 0.0163
#   Term: ice, TF-IDF Score: 0.0163
#   Term: meets, TF-IDF Score: 0.0163
#   Term: lost, TF-IDF Score: 0.0163
#   Term: competition, TF-IDF Score: 0.0163
#   Term: johto, TF-IDF Score: 0.0163
#   Term: conference, TF-IDF Score: 0.0163
#   Term: captures, TF-IDF Score: 0.0163
#   Term: fighting, TF-IDF Score: 0.0163
#   Term: wonders, TF-IDF Score: 0.0163
#   Term: npc, TF-IDF Score: 0.0163
#   Term: cave, TF-IDF Score: 0.0163
#   Term: areas, TF-IDF Score: 0.0163
#   Term: unique, TF-IDF Score: 0.0163
#   Term: sun, TF-IDF Score: 0.0163
#   Term: near, TF-IDF Score: 0.0163
#   Term: obtainable, TF-IDF Score: 0.0163
#   Term: item, TF-IDF Score: 0.0163
#   Term: extremely, TF-IDF Score: 0.0163
#   Term: colored, TF-IDF Score: 0.0163
#   Term: cream, TF-IDF Score: 0.0163
#   Term: far, TF-IDF Score: 0.0163
#   Term: mixed, TF-IDF Score: 0.0163
#   Term: utilized, TF-IDF Score: 0.0163
#   Term: says, TF-IDF Score: 0.0163
#   Term: chick, TF-IDF Score: 0.0163
#   Term: year, TF-IDF Score: 0.0163
#   Term: lipperini, TF-IDF Score: 0.0163
#   Term: caught, TF-IDF Score: 0.0163
#   Term: darkness, TF-IDF Score: 0.0163
#   Term: rescue, TF-IDF Score: 0.0163
#   Term: frenzy, TF-IDF Score: 0.0163
#   Term: appearances, TF-IDF Score: 0.0163
#   Term: make, TF-IDF Score: 0.0163
#   Term: appearance, TF-IDF Score: 0.0163
#   Term: team, TF-IDF Score: 0.0163
#   Term: generation, TF-IDF Score: 0.0163
#   Term: reception, TF-IDF Score: 0.0163
#   Term: adventures, TF-IDF Score: 0.0163
#   Term: animated, TF-IDF Score: 0.0163
#   Term: merchandise, TF-IDF Score: 0.0163
#   Term: sugimori, TF-IDF Score: 0.0163
#   Term: ken, TF-IDF Score: 0.0163
#   Term: franchise, TF-IDF Score: 0.0163
#   Term: nintendo, TF-IDF Score: 0.0163
#   Term: popularity, TF-IDF Score: 0.0145
#   Term: placed, TF-IDF Score: 0.0145
#   Term: praised, TF-IDF Score: 0.0145
#   Term: legendary, TF-IDF Score: 0.0145
#   Term: non, TF-IDF Score: 0.0145
#   Term: way, TF-IDF Score: 0.0145
#   Term: members, TF-IDF Score: 0.0145
#   Term: frontier, TF-IDF Score: 0.0145
#   Term: helped, TF-IDF Score: 0.0145
#   Term: younger, TF-IDF Score: 0.0145
#   Term: gets, TF-IDF Score: 0.0145
#   Term: match, TF-IDF Score: 0.0145
#   Term: quickly, TF-IDF Score: 0.0145
#   Term: oak, TF-IDF Score: 0.0145
#   Term: defeat, TF-IDF Score: 0.0145
#   Term: owner, TF-IDF Score: 0.0145
#   Term: does, TF-IDF Score: 0.0145
#   Term: boss, TF-IDF Score: 0.0145
#   Term: bring, TF-IDF Score: 0.0145
#   Term: region, TF-IDF Score: 0.0145
#   Term: arms, TF-IDF Score: 0.0145
#   Term: stand, TF-IDF Score: 0.0145
#   Term: small, TF-IDF Score: 0.0145
#   Term: constant, TF-IDF Score: 0.0145
#   Term: day, TF-IDF Score: 0.0145
#   Term: tower, TF-IDF Score: 0.0145
#   Term: obtain, TF-IDF Score: 0.0145
#   Term: official, TF-IDF Score: 0.0131
#   Term: light, TF-IDF Score: 0.0131
#   Term: alongside, TF-IDF Score: 0.0131
#   Term: normal, TF-IDF Score: 0.0131
#   Term: sleep, TF-IDF Score: 0.0131
#   Term: promotion, TF-IDF Score: 0.0131
#   Term: friends, TF-IDF Score: 0.0131
#   Term: league, TF-IDF Score: 0.0131
#   Term: melee, TF-IDF Score: 0.0131
#   Term: moon, TF-IDF Score: 0.0131
#   Term: power, TF-IDF Score: 0.0131
#   Term: place, TF-IDF Score: 0.0131
#   Term: long, TF-IDF Score: 0.0131
#   Term: short, TF-IDF Score: 0.0131
#   Term: color, TF-IDF Score: 0.0131
#   Term: face, TF-IDF Score: 0.0131
#   Term: words, TF-IDF Score: 0.0131
#   Term: renamed, TF-IDF Score: 0.0131
#   Term: favorite, TF-IDF Score: 0.0131
#   Term: describing, TF-IDF Score: 0.0131
#   Term: sequel, TF-IDF Score: 0.0131
#   Term: combination, TF-IDF Score: 0.0131
#   Term: introduced, TF-IDF Score: 0.0131
#   Term: positive, TF-IDF Score: 0.0131
#   Term: ranked, TF-IDF Score: 0.0118
#   Term: defeated, TF-IDF Score: 0.0118
#   Term: islands, TF-IDF Score: 0.0118
#   Term: episodes, TF-IDF Score: 0.0118
#   Term: ball, TF-IDF Score: 0.0118
#   Term: eventually, TF-IDF Score: 0.0118
#   Term: kanto, TF-IDF Score: 0.0118
#   Term: role, TF-IDF Score: 0.0118
#   Term: having, TF-IDF Score: 0.0118
#   Term: hands, TF-IDF Score: 0.0118
#   Term: versions, TF-IDF Score: 0.0118
#   Term: wii, TF-IDF Score: 0.0118
#   Term: makes, TF-IDF Score: 0.0118
#   Term: crystal, TF-IDF Score: 0.0118
#   Term: final, TF-IDF Score: 0.0118
#   Term: finalized, TF-IDF Score: 0.0118
#   Term: conceived, TF-IDF Score: 0.0118
#   Term: originally, TF-IDF Score: 0.0118
#   Term: imdb, TF-IDF Score: 0.0107
#   Term: despite, TF-IDF Score: 0.0107
#   Term: uses, TF-IDF Score: 0.0107
#   Term: episode, TF-IDF Score: 0.0107
#   Term: language, TF-IDF Score: 0.0107
#   Term: attack, TF-IDF Score: 0.0107
#   Term: end, TF-IDF Score: 0.0107
#   Term: snap, TF-IDF Score: 0.0107
#   Term: pearl, TF-IDF Score: 0.0107
#   Term: diamond, TF-IDF Score: 0.0107
#   Term: relatable, TF-IDF Score: 0.0107
#   Term: western, TF-IDF Score: 0.0107
#   Term: translating, TF-IDF Score: 0.0107
#   Term: descriptive, TF-IDF Score: 0.0107
#   Term: clever, TF-IDF Score: 0.0107
#   Term: decided, TF-IDF Score: 0.0107
#   Term: localized, TF-IDF Score: 0.0107
#   Term: appearing, TF-IDF Score: 0.0107
#   Term: popular, TF-IDF Score: 0.0098
#   Term: named, TF-IDF Score: 0.0098
#   Term: gamesradar, TF-IDF Score: 0.0098
#   Term: white, TF-IDF Score: 0.0098
#   Term: original, TF-IDF Score: 0.0098
#   Term: means, TF-IDF Score: 0.0098
#   Term: names, TF-IDF Score: 0.0098
#   Term: outside, TF-IDF Score: 0.0098
#   Term: monsters, TF-IDF Score: 0.0098
#   Term: pocket, TF-IDF Score: 0.0098
#   Term: development, TF-IDF Score: 0.0098
#   Term: different, TF-IDF Score: 0.0098
#   Term: titles, TF-IDF Score: 0.0098
#   Term: spinoff, TF-IDF Score: 0.0098
#   Term: subsequent, TF-IDF Score: 0.0098
#   Term: created, TF-IDF Score: 0.0098
#   Term: gold, TF-IDF Score: 0.0089
#   Term: characters, TF-IDF Score: 0.0089
#   Term: audiences, TF-IDF Score: 0.0089
#   Term: features, TF-IDF Score: 0.0089
#   Term: related, TF-IDF Score: 0.0089
#   Term: silver, TF-IDF Score: 0.0089
#   Term: english, TF-IDF Score: 0.0089
#   Term: sequels, TF-IDF Score: 0.0089
#   Term: green, TF-IDF Score: 0.0089
#   Term: bulbapedia, TF-IDF Score: 0.0081
#   Term: links, TF-IDF Score: 0.0081
#   Term: external, TF-IDF Score: 0.0081
#   Term: references, TF-IDF Score: 0.0081
#   Term: manga, TF-IDF Score: 0.0081
#   Term: adaptations, TF-IDF Score: 0.0081
#   Term: printed, TF-IDF Score: 0.0081
#   Term: appeared, TF-IDF Score: 0.0081
#
# Document: a2.txt
#   Term: ash, TF-IDF Score: 0.5425
#   Term: pokémon, TF-IDF Score: 0.3894
#   Term: league, TF-IDF Score: 0.1757
#   Term: badges, TF-IDF Score: 0.1302
#   Term: character, TF-IDF Score: 0.1225
#   Term: anime, TF-IDF Score: 0.1225
#   Term: series, TF-IDF Score: 0.1198
#   Term: rival, TF-IDF Score: 0.1107
#   Term: pikachu, TF-IDF Score: 0.1103
#   Term: trainer, TF-IDF Score: 0.1095
#   Term: taylor, TF-IDF Score: 0.1065
#   Term: greninja, TF-IDF Score: 0.1006
#   Term: finals, TF-IDF Score: 0.0947
#   Term: kalos, TF-IDF Score: 0.0905
#   Term: conference, TF-IDF Score: 0.0880
#   Term: ketchum, TF-IDF Score: 0.0861
#   Term: parody, TF-IDF Score: 0.0828
#   Term: sinnoh, TF-IDF Score: 0.0828
#   Term: satoshi, TF-IDF Score: 0.0805
#   Term: new, TF-IDF Score: 0.0762
#   Term: episode, TF-IDF Score: 0.0750
#   Term: season, TF-IDF Score: 0.0710
#   Term: frontier, TF-IDF Score: 0.0704
#   Term: team, TF-IDF Score: 0.0700
#   Term: battle, TF-IDF Score: 0.0692
#   Term: brock, TF-IDF Score: 0.0616
#   Term: gary, TF-IDF Score: 0.0616
#   Term: unova, TF-IDF Score: 0.0604
#   Term: previous, TF-IDF Score: 0.0604
#   Term: tajiri, TF-IDF Score: 0.0604
#   Term: trip, TF-IDF Score: 0.0592
#   Term: master, TF-IDF Score: 0.0592
#   Term: orange, TF-IDF Score: 0.0548
#   Term: region, TF-IDF Score: 0.0548
#   Term: journey, TF-IDF Score: 0.0528
#   Term: red, TF-IDF Score: 0.0525
#   Term: defeated, TF-IDF Score: 0.0508
#   Term: alain, TF-IDF Score: 0.0503
#   Term: voice, TF-IDF Score: 0.0503
#   Term: win, TF-IDF Score: 0.0503
#   Term: mega, TF-IDF Score: 0.0492
#   Term: tv, TF-IDF Score: 0.0473
#   Term: tobias, TF-IDF Score: 0.0473
#   Term: quarter, TF-IDF Score: 0.0473
#   Term: competed, TF-IDF Score: 0.0473
#   Term: traveled, TF-IDF Score: 0.0473
#   Term: rivals, TF-IDF Score: 0.0473
#   Term: shigeru, TF-IDF Score: 0.0473
#   Term: taken, TF-IDF Score: 0.0473
#   Term: round, TF-IDF Score: 0.0469
#   Term: lost, TF-IDF Score: 0.0440
#   Term: johto, TF-IDF Score: 0.0440
#   Term: world, TF-IDF Score: 0.0440
#   Term: characters, TF-IDF Score: 0.0431
#   Term: japanese, TF-IDF Score: 0.0431
#   Term: powerful, TF-IDF Score: 0.0422
#   Term: misty, TF-IDF Score: 0.0422
#   Term: named, TF-IDF Score: 0.0420
#   Term: pallet, TF-IDF Score: 0.0402
#   Term: seasons, TF-IDF Score: 0.0402
#   Term: group, TF-IDF Score: 0.0402
#   Term: games, TF-IDF Score: 0.0394
#   Term: town, TF-IDF Score: 0.0391
#   Term: time, TF-IDF Score: 0.0368
#   Term: reference, TF-IDF Score: 0.0355
#   Term: outfit, TF-IDF Score: 0.0355
#   Term: phenomenon, TF-IDF Score: 0.0355
#   Term: transformation, TF-IDF Score: 0.0355
#   Term: cameron, TF-IDF Score: 0.0355
#   Term: farewell, TF-IDF Score: 0.0355
#   Term: ranking, TF-IDF Score: 0.0355
#   Term: symbols, TF-IDF Score: 0.0355
#   Term: 2nd, TF-IDF Score: 0.0355
#   Term: champion, TF-IDF Score: 0.0355
#   Term: achieve, TF-IDF Score: 0.0355
#   Term: compete, TF-IDF Score: 0.0355
#   Term: specifically, TF-IDF Score: 0.0355
#   Term: serena, TF-IDF Score: 0.0355
#   Term: camp, TF-IDF Score: 0.0355
#   Term: xy, TF-IDF Score: 0.0355
#   Term: leagues, TF-IDF Score: 0.0355
#   Term: em, TF-IDF Score: 0.0355
#   Term: gotta, TF-IDF Score: 0.0355
#   Term: bond, TF-IDF Score: 0.0352
#   Term: fans, TF-IDF Score: 0.0352
#   Term: protagonist, TF-IDF Score: 0.0352
#   Term: sun, TF-IDF Score: 0.0352
#   Term: defeats, TF-IDF Score: 0.0352
#   Term: brain, TF-IDF Score: 0.0352
#   Term: gym, TF-IDF Score: 0.0351
#   Term: game, TF-IDF Score: 0.0350
#   Term: able, TF-IDF Score: 0.0346
#   Term: rocket, TF-IDF Score: 0.0346
#   Term: like, TF-IDF Score: 0.0335
#   Term: having, TF-IDF Score: 0.0318
#   Term: makes, TF-IDF Score: 0.0318
#   Term: capable, TF-IDF Score: 0.0313
#   Term: major, TF-IDF Score: 0.0313
#   Term: choose, TF-IDF Score: 0.0313
#   Term: catch, TF-IDF Score: 0.0313
#   Term: alola, TF-IDF Score: 0.0302
#   Term: island, TF-IDF Score: 0.0302
#   Term: stronger, TF-IDF Score: 0.0302
#   Term: indigo, TF-IDF Score: 0.0302
#   Term: starter, TF-IDF Score: 0.0302
#   Term: met, TF-IDF Score: 0.0302
#   Term: childhood, TF-IDF Score: 0.0302
#   Term: making, TF-IDF Score: 0.0302
#   Term: work, TF-IDF Score: 0.0302
#   Term: line, TF-IDF Score: 0.0302
#   Term: late, TF-IDF Score: 0.0302
#   Term: ring, TF-IDF Score: 0.0302
#   Term: traveling, TF-IDF Score: 0.0302
#   Term: obtained, TF-IDF Score: 0.0302
#   Term: moon, TF-IDF Score: 0.0281
#   Term: learn, TF-IDF Score: 0.0281
#   Term: befriends, TF-IDF Score: 0.0264
#   Term: hoenn, TF-IDF Score: 0.0264
#   Term: decides, TF-IDF Score: 0.0264
#   Term: far, TF-IDF Score: 0.0264
#   Term: flare, TF-IDF Score: 0.0264
#   Term: including, TF-IDF Score: 0.0263
#   Term: blue, TF-IDF Score: 0.0263
#   Term: manga, TF-IDF Score: 0.0263
#   Term: islands, TF-IDF Score: 0.0254
#   Term: kanto, TF-IDF Score: 0.0254
#   Term: player, TF-IDF Score: 0.0254
#   Term: known, TF-IDF Score: 0.0240
#   Term: english, TF-IDF Score: 0.0240
#   Term: cartoon, TF-IDF Score: 0.0237
#   Term: johnny, TF-IDF Score: 0.0237
#   Term: wearing, TF-IDF Score: 0.0237
#   Term: norm, TF-IDF Score: 0.0237
#   Term: title, TF-IDF Score: 0.0237
#   Term: length, TF-IDF Score: 0.0237
#   Term: bart, TF-IDF Score: 0.0237
#   Term: simpsons, TF-IDF Score: 0.0237
#   Term: brief, TF-IDF Score: 0.0237
#   Term: parodies, TF-IDF Score: 0.0237
#   Term: frequently, TF-IDF Score: 0.0237
#   Term: imagined, TF-IDF Score: 0.0237
#   Term: trial, TF-IDF Score: 0.0237
#   Term: collected, TF-IDF Score: 0.0237
#   Term: course, TF-IDF Score: 0.0237
#   Term: improved, TF-IDF Score: 0.0237
#   Term: melemele, TF-IDF Score: 0.0237
#   Term: local, TF-IDF Score: 0.0237
#   Term: lumiose, TF-IDF Score: 0.0237
#   Term: plasma, TF-IDF Score: 0.0237
#   Term: virgil, TF-IDF Score: 0.0237
#   Term: bids, TF-IDF Score: 0.0237
#   Term: darkrai, TF-IDF Score: 0.0237
#   Term: semi, TF-IDF Score: 0.0237
#   Term: lily, TF-IDF Score: 0.0237
#   Term: competes, TF-IDF Score: 0.0237
#   Term: encounter, TF-IDF Score: 0.0237
#   Term: paul, TF-IDF Score: 0.0237
#   Term: dawn, TF-IDF Score: 0.0237
#   Term: future, TF-IDF Score: 0.0237
#   Term: acquires, TF-IDF Score: 0.0237
#   Term: brains, TF-IDF Score: 0.0237
#   Term: 1st, TF-IDF Score: 0.0237
#   Term: 16, TF-IDF Score: 0.0237
#   Term: skill, TF-IDF Score: 0.0237
#   Term: getting, TF-IDF Score: 0.0237
#   Term: earned, TF-IDF Score: 0.0237
#   Term: lot, TF-IDF Score: 0.0237
#   Term: differences, TF-IDF Score: 0.0237
#   Term: occasionally, TF-IDF Score: 0.0237
#   Term: stopped, TF-IDF Score: 0.0237
#   Term: comical, TF-IDF Score: 0.0237
#   Term: offered, TF-IDF Score: 0.0237
#   Term: hurt, TF-IDF Score: 0.0237
#   Term: summer, TF-IDF Score: 0.0237
#   Term: seventeenth, TF-IDF Score: 0.0237
#   Term: kept, TF-IDF Score: 0.0237
#   Term: tree, TF-IDF Score: 0.0237
#   Term: shelter, TF-IDF Score: 0.0237
#   Term: rain, TF-IDF Score: 0.0237
#   Term: xyz, TF-IDF Score: 0.0237
#   Term: consistency, TF-IDF Score: 0.0237
#   Term: recorded, TF-IDF Score: 0.0237
#   Term: flap, TF-IDF Score: 0.0237
#   Term: lip, TF-IDF Score: 0.0237
#   Term: 2016, TF-IDF Score: 0.0237
#   Term: represented, TF-IDF Score: 0.0237
#   Term: catching, TF-IDF Score: 0.0237
#   Term: timeline, TF-IDF Score: 0.0237
#   Term: floating, TF-IDF Score: 0.0237
#   Term: natochenny, TF-IDF Score: 0.0237
#   Term: sarah, TF-IDF Score: 0.0237
#   Term: veronica, TF-IDF Score: 0.0237
#   Term: matsumoto, TF-IDF Score: 0.0237
#   Term: rica, TF-IDF Score: 0.0237
#   Term: criticized, TF-IDF Score: 0.0235
#   Term: puzzle, TF-IDF Score: 0.0235
#   Term: legendary, TF-IDF Score: 0.0235
#   Term: way, TF-IDF Score: 0.0235
#   Term: oak, TF-IDF Score: 0.0235
#   Term: defeat, TF-IDF Score: 0.0235
#   Term: travel, TF-IDF Score: 0.0235
#   Term: changes, TF-IDF Score: 0.0235
#   Term: yellow, TF-IDF Score: 0.0235
#   Term: similar, TF-IDF Score: 0.0231
#   Term: video, TF-IDF Score: 0.0219
#   Term: franchise, TF-IDF Score: 0.0219
#   Term: help, TF-IDF Score: 0.0211
#   Term: friends, TF-IDF Score: 0.0211
#   Term: considered, TF-IDF Score: 0.0211
#   Term: original, TF-IDF Score: 0.0210
#   Term: stay, TF-IDF Score: 0.0201
#   Term: powers, TF-IDF Score: 0.0201
#   Term: began, TF-IDF Score: 0.0201
#   Term: temporary, TF-IDF Score: 0.0201
#   Term: ways, TF-IDF Score: 0.0201
#   Term: valley, TF-IDF Score: 0.0201
#   Term: challenge, TF-IDF Score: 0.0201
#   Term: finally, TF-IDF Score: 0.0201
#   Term: meet, TF-IDF Score: 0.0201
#   Term: fact, TF-IDF Score: 0.0201
#   Term: travels, TF-IDF Score: 0.0201
#   Term: member, TF-IDF Score: 0.0201
#   Term: organization, TF-IDF Score: 0.0201
#   Term: took, TF-IDF Score: 0.0201
#   Term: lines, TF-IDF Score: 0.0201
#   Term: replaced, TF-IDF Score: 0.0201
#   Term: particular, TF-IDF Score: 0.0201
#   Term: culture, TF-IDF Score: 0.0201
#   Term: pop, TF-IDF Score: 0.0201
#   Term: mascot, TF-IDF Score: 0.0201
#   Term: gone, TF-IDF Score: 0.0201
#   Term: loosely, TF-IDF Score: 0.0201
#   Term: iii, TF-IDF Score: 0.0201
#   Term: surge, TF-IDF Score: 0.0201
#   Term: japan, TF-IDF Score: 0.0192
#   Term: received, TF-IDF Score: 0.0192
#   Term: appears, TF-IDF Score: 0.0192
#   Term: given, TF-IDF Score: 0.0191
#   Term: stated, TF-IDF Score: 0.0191
#   Term: episodes, TF-IDF Score: 0.0191
#   Term: electric, TF-IDF Score: 0.0191
#   Term: type, TF-IDF Score: 0.0191
#   Term: cameo, TF-IDF Score: 0.0176
#   Term: abilities, TF-IDF Score: 0.0176
#   Term: evil, TF-IDF Score: 0.0176
#   Term: draw, TF-IDF Score: 0.0176
#   Term: drake, TF-IDF Score: 0.0176
#   Term: love, TF-IDF Score: 0.0176
#   Term: companions, TF-IDF Score: 0.0176
#   Term: squirtle, TF-IDF Score: 0.0176
#   Term: point, TF-IDF Score: 0.0176
#   Term: little, TF-IDF Score: 0.0176
#   Term: know, TF-IDF Score: 0.0176
#   Term: believed, TF-IDF Score: 0.0176
#   Term: great, TF-IDF Score: 0.0176
#   Term: provided, TF-IDF Score: 0.0176
#   Term: started, TF-IDF Score: 0.0176
#   Term: felt, TF-IDF Score: 0.0176
#   Term: meets, TF-IDF Score: 0.0176
#   Term: giving, TF-IDF Score: 0.0176
#   Term: inspired, TF-IDF Score: 0.0176
#   Term: man, TF-IDF Score: 0.0176
#   Term: caught, TF-IDF Score: 0.0176
#   Term: went, TF-IDF Score: 0.0176
#   Term: dragon, TF-IDF Score: 0.0176
#   Term: appearance, TF-IDF Score: 0.0175
#   Term: generation, TF-IDF Score: 0.0175
#   Term: media, TF-IDF Score: 0.0175
#   Term: order, TF-IDF Score: 0.0173
#   Term: despite, TF-IDF Score: 0.0173
#   Term: remakes, TF-IDF Score: 0.0173
#   Term: said, TF-IDF Score: 0.0173
#   Term: based, TF-IDF Score: 0.0173
#   Term: evolved, TF-IDF Score: 0.0173
#   Term: voiced, TF-IDF Score: 0.0158
#   Term: list, TF-IDF Score: 0.0156
#   Term: unlike, TF-IDF Score: 0.0156
#   Term: opponents, TF-IDF Score: 0.0156
#   Term: faces, TF-IDF Score: 0.0156
#   Term: battling, TF-IDF Score: 0.0156
#   Term: professor, TF-IDF Score: 0.0156
#   Term: energy, TF-IDF Score: 0.0156
#   Term: playing, TF-IDF Score: 0.0156
#   Term: adapted, TF-IDF Score: 0.0156
#   Term: interview, TF-IDF Score: 0.0156
#   Term: just, TF-IDF Score: 0.0156
#   Term: included, TF-IDF Score: 0.0156
#   Term: dub, TF-IDF Score: 0.0156
#   Term: younger, TF-IDF Score: 0.0156
#   Term: gets, TF-IDF Score: 0.0156
#   Term: match, TF-IDF Score: 0.0156
#   Term: does, TF-IDF Score: 0.0156
#   Term: commented, TF-IDF Score: 0.0156
#   Term: special, TF-IDF Score: 0.0156
#   Term: attempts, TF-IDF Score: 0.0156
#   Term: concept, TF-IDF Score: 0.0156
#   Term: evolution, TF-IDF Score: 0.0144
#   Term: cited, TF-IDF Score: 0.0141
#   Term: second, TF-IDF Score: 0.0141
#   Term: favorite, TF-IDF Score: 0.0141
#   Term: tale, TF-IDF Score: 0.0141
#   Term: appearances, TF-IDF Score: 0.0131
#   Term: called, TF-IDF Score: 0.0131
#   Term: animated, TF-IDF Score: 0.0131
#   Term: various, TF-IDF Score: 0.0131
#   Term: stating, TF-IDF Score: 0.0127
#   Term: instead, TF-IDF Score: 0.0127
#   Term: ball, TF-IDF Score: 0.0127
#   Term: eventually, TF-IDF Score: 0.0127
#   Term: certain, TF-IDF Score: 0.0127
#   Term: james, TF-IDF Score: 0.0127
#   Term: serebii, TF-IDF Score: 0.0118
#   Term: disappointment, TF-IDF Score: 0.0118
#   Term: animators, TF-IDF Score: 0.0118
#   Term: conventional, TF-IDF Score: 0.0118
#   Term: resist, TF-IDF Score: 0.0118
#   Term: advantages, TF-IDF Score: 0.0118
#   Term: outcome, TF-IDF Score: 0.0118
#   Term: disliked, TF-IDF Score: 0.0118
#   Term: trailers, TF-IDF Score: 0.0118
#   Term: misleading, TF-IDF Score: 0.0118
#   Term: fandom, TF-IDF Score: 0.0118
#   Term: criticism, TF-IDF Score: 0.0118
#   Term: finish, TF-IDF Score: 0.0118
#   Term: fiery, TF-IDF Score: 0.0118
#   Term: kessen, TF-IDF Score: 0.0118
#   Term: chōjō, TF-IDF Score: 0.0118
#   Term: yūshō, TF-IDF Score: 0.0118
#   Term: karosurīgu, TF-IDF Score: 0.0118
#   Term: サトシ頂上決戦, TF-IDF Score: 0.0118
#   Term: カロスリーグ優勝, TF-IDF Score: 0.0118
#   Term: decisive, TF-IDF Score: 0.0118
#   Term: victory, TF-IDF Score: 0.0118
#   Term: 18, TF-IDF Score: 0.0118
#   Term: august, TF-IDF Score: 0.0118
#   Term: mueller, TF-IDF Score: 0.0118
#   Term: robert, TF-IDF Score: 0.0118
#   Term: prosecutor, TF-IDF Score: 0.0118
#   Term: trump, TF-IDF Score: 0.0118
#   Term: donald, TF-IDF Score: 0.0118
#   Term: colbert, TF-IDF Score: 0.0118
#   Term: stephen, TF-IDF Score: 0.0118
#   Term: sending, TF-IDF Score: 0.0118
#   Term: phrase, TF-IDF Score: 0.0118
#   Term: spirit, TF-IDF Score: 0.0118
#   Term: hanzo, TF-IDF Score: 0.0118
#   Term: overwatch, TF-IDF Score: 0.0118
#   Term: blatant, TF-IDF Score: 0.0118
#   Term: ketchup, TF-IDF Score: 0.0118
#   Term: test, TF-IDF Score: 0.0118
#   Term: metalocalypse, TF-IDF Score: 0.0118
#   Term: hat, TF-IDF Score: 0.0118
#   Term: expo, TF-IDF Score: 0.0118
#   Term: procedures, TF-IDF Score: 0.0118
#   Term: safety, TF-IDF Score: 0.0118
#   Term: basic, TF-IDF Score: 0.0118
#   Term: passengers, TF-IDF Score: 0.0118
#   Term: ads, TF-IDF Score: 0.0118
#   Term: subway, TF-IDF Score: 0.0118
#   Term: taiwanese, TF-IDF Score: 0.0118
#   Term: rabies, TF-IDF Score: 0.0118
# ...
#   Term: wings, TF-IDF Score: 0.0327
#   Term: shiny, TF-IDF Score: 0.0327
#   Term: player, TF-IDF Score: 0.0315
#   Term: evolution, TF-IDF Score: 0.0297
#   Term: silver, TF-IDF Score: 0.0297
#   Term: maya, TF-IDF Score: 0.0293
#   Term: arceus, TF-IDF Score: 0.0293
#   Term: hatched, TF-IDF Score: 0.0293
#   Term: kingdom, TF-IDF Score: 0.0293
#   Term: metronome, TF-IDF Score: 0.0293
#   Term: elm, TF-IDF Score: 0.0293
#   Term: patterns, TF-IDF Score: 0.0293
#   Term: triangular, TF-IDF Score: 0.0293
#   Term: dove, TF-IDF Score: 0.0293
#   Term: blue, TF-IDF Score: 0.0271
#   Term: red, TF-IDF Score: 0.0271
#   Term: appeared, TF-IDF Score: 0.0271
#   Term: second, TF-IDF Score: 0.0261
#   Term: forms, TF-IDF Score: 0.0261
#   Term: baby, TF-IDF Score: 0.0249
#   Term: visible, TF-IDF Score: 0.0249
#   Term: pair, TF-IDF Score: 0.0249
#   Term: neck, TF-IDF Score: 0.0249
#   Term: newly, TF-IDF Score: 0.0249
#   Term: immediately, TF-IDF Score: 0.0249
#   Term: prehistoric, TF-IDF Score: 0.0249
#   Term: previous, TF-IDF Score: 0.0249
#   Term: commenting, TF-IDF Score: 0.0249
#   Term: gaining, TF-IDF Score: 0.0249
#   Term: like, TF-IDF Score: 0.0237
#   Term: body, TF-IDF Score: 0.0237
#   Term: design, TF-IDF Score: 0.0237
#   Term: patricia, TF-IDF Score: 0.0218
#   Term: scene, TF-IDF Score: 0.0218
#   Term: mother, TF-IDF Score: 0.0218
#   Term: know, TF-IDF Score: 0.0218
#   Term: giving, TF-IDF Score: 0.0218
#   Term: inspired, TF-IDF Score: 0.0218
#   Term: dreams, TF-IDF Score: 0.0218
#   Term: stop, TF-IDF Score: 0.0218
#   Term: appearance, TF-IDF Score: 0.0217
#   Term: called, TF-IDF Score: 0.0217
#   Term: games, TF-IDF Score: 0.0217
#   Term: game, TF-IDF Score: 0.0217
#   Term: episode, TF-IDF Score: 0.0214
#   Term: pearl, TF-IDF Score: 0.0214
#   Term: diamond, TF-IDF Score: 0.0214
#   Term: author, TF-IDF Score: 0.0195
#   Term: editor, TF-IDF Score: 0.0195
#   Term: unlike, TF-IDF Score: 0.0194
#   Term: round, TF-IDF Score: 0.0194
#   Term: professor, TF-IDF Score: 0.0194
#   Term: younger, TF-IDF Score: 0.0194
#   Term: bring, TF-IDF Score: 0.0194
#   Term: readers, TF-IDF Score: 0.0194
#   Term: commented, TF-IDF Score: 0.0194
#   Term: release, TF-IDF Score: 0.0194
#   Term: described, TF-IDF Score: 0.0178
#   Term: appears, TF-IDF Score: 0.0178
#   Term: people, TF-IDF Score: 0.0174
#   Term: protect, TF-IDF Score: 0.0174
#   Term: moon, TF-IDF Score: 0.0174
#   Term: long, TF-IDF Score: 0.0174
#   Term: feet, TF-IDF Score: 0.0174
#   Term: attacks, TF-IDF Score: 0.0174
#   Term: evolve, TF-IDF Score: 0.0174
#   Term: evolving, TF-IDF Score: 0.0174
#   Term: positive, TF-IDF Score: 0.0174
#   Term: appear, TF-IDF Score: 0.0174
#   Term: times, TF-IDF Score: 0.0174
#   Term: ash, TF-IDF Score: 0.0163
#   Term: character, TF-IDF Score: 0.0163
#   Term: video, TF-IDF Score: 0.0163
#   Term: good, TF-IDF Score: 0.0157
#   Term: eventually, TF-IDF Score: 0.0157
#   Term: smash, TF-IDF Score: 0.0157
#   Term: final, TF-IDF Score: 0.0157
#   Term: website, TF-IDF Score: 0.0147
#   Term: hard, TF-IDF Score: 0.0147
#   Term: aide, TF-IDF Score: 0.0147
#   Term: collegian, TF-IDF Score: 0.0147
#   Term: independent, TF-IDF Score: 0.0147
#   Term: needing, TF-IDF Score: 0.0147
#   Term: symbolized, TF-IDF Score: 0.0147
#   Term: phase, TF-IDF Score: 0.0147
#   Term: suggests, TF-IDF Score: 0.0147
#   Term: milk, TF-IDF Score: 0.0147
#   Term: land, TF-IDF Score: 0.0147
#   Term: manikin, TF-IDF Score: 0.0147
#   Term: discussion, TF-IDF Score: 0.0147
#   Term: götz, TF-IDF Score: 0.0147
#   Term: disneyland, TF-IDF Score: 0.0147
#   Term: potter, TF-IDF Score: 0.0147
#   Term: babies, TF-IDF Score: 0.0147
#   Term: fantasize, TF-IDF Score: 0.0147
#   Term: jones, TF-IDF Score: 0.0147
#   Term: gerard, TF-IDF Score: 0.0147
#   Term: toddler, TF-IDF Score: 0.0147
#   Term: overactive, TF-IDF Score: 0.0147
#   Term: instincts, TF-IDF Score: 0.0147
#   Term: motherly, TF-IDF Score: 0.0147
#   Term: mark, TF-IDF Score: 0.0147
#   Term: miyazaki, TF-IDF Score: 0.0147
#   Term: fatty, TF-IDF Score: 0.0147
#   Term: plump, TF-IDF Score: 0.0147
#   Term: pleasantly, TF-IDF Score: 0.0147
#   Term: annoying, TF-IDF Score: 0.0147
#   Term: claiming, TF-IDF Score: 0.0147
#   Term: boring, TF-IDF Score: 0.0147
#   Term: criticize, TF-IDF Score: 0.0147
#   Term: cutest, TF-IDF Score: 0.0147
#   Term: nominee, TF-IDF Score: 0.0147
#   Term: lovable, TF-IDF Score: 0.0147
#   Term: parker, TF-IDF Score: 0.0147
#   Term: fiona, TF-IDF Score: 0.0147
#   Term: mirror, TF-IDF Score: 0.0147
#   Term: airplane, TF-IDF Score: 0.0147
#   Term: plated, TF-IDF Score: 0.0147
#   Term: 23k, TF-IDF Score: 0.0147
#   Term: promotions, TF-IDF Score: 0.0147
#   Term: king, TF-IDF Score: 0.0147
#   Term: burger, TF-IDF Score: 0.0147
#   Term: promotional, TF-IDF Score: 0.0147
#   Term: pieces, TF-IDF Score: 0.0147
#   Term: damage, TF-IDF Score: 0.0147
#   Term: deal, TF-IDF Score: 0.0147
#   Term: enables, TF-IDF Score: 0.0147
#   Term: alph, TF-IDF Score: 0.0147
#   Term: ruins, TF-IDF Score: 0.0147
#   Term: considerable, TF-IDF Score: 0.0147
#   Term: habits, TF-IDF Score: 0.0147
#   Term: gambling, TF-IDF Score: 0.0147
#   Term: picked, TF-IDF Score: 0.0147
#   Term: gligar, TF-IDF Score: 0.0147
#   Term: facial, TF-IDF Score: 0.0147
#   Term: regular, TF-IDF Score: 0.0147
#   Term: jasmine, TF-IDF Score: 0.0147
#   Term: spaceship, TF-IDF Score: 0.0147
#   Term: aboard, TF-IDF Score: 0.0147
#   Term: space, TF-IDF Score: 0.0147
#   Term: tricks, TF-IDF Score: 0.0147
#   Term: let, TF-IDF Score: 0.0147
#   Term: paradise, TF-IDF Score: 0.0147
#   Term: inseparable, TF-IDF Score: 0.0147
#   Term: grows, TF-IDF Score: 0.0147
#   Term: clearer, TF-IDF Score: 0.0147
#   Term: anticipating, TF-IDF Score: 0.0147
#   Term: imprinting, TF-IDF Score: 0.0147
#   Term: filial, TF-IDF Score: 0.0147
#   Term: believes, TF-IDF Score: 0.0147
#   Term: sees, TF-IDF Score: 0.0147
#   Term: thing, TF-IDF Score: 0.0147
#   Term: hatches, TF-IDF Score: 0.0147
#   Term: summon, TF-IDF Score: 0.0147
#   Term: minis, TF-IDF Score: 0.0147
#   Term: crawling, TF-IDF Score: 0.0147
#   Term: kinds, TF-IDF Score: 0.0147
#   Term: avoiding, TF-IDF Score: 0.0147
#   Term: yards, TF-IDF Score: 0.0147
#   Term: wobble, TF-IDF Score: 0.0147
#   Term: tumbling, TF-IDF Score: 0.0147
#   Term: minigame, TF-IDF Score: 0.0147
#   Term: stars, TF-IDF Score: 0.0147
#   Term: cynthia, TF-IDF Score: 0.0147
#   Term: national, TF-IDF Score: 0.0147
#   Term: generations, TF-IDF Score: 0.0147
#   Term: debuted, TF-IDF Score: 0.0147
#   Term: avian, TF-IDF Score: 0.0147
#   Term: slight, TF-IDF Score: 0.0147
#   Term: noticeably, TF-IDF Score: 0.0147
#   Term: accentuated, TF-IDF Score: 0.0147
#   Term: torso, TF-IDF Score: 0.0147
#   Term: sufficiently, TF-IDF Score: 0.0147
#   Term: required, TF-IDF Score: 0.0147
#   Term: twice, TF-IDF Score: 0.0147
#   Term: strife, TF-IDF Score: 0.0147
#   Term: lack, TF-IDF Score: 0.0147
#   Term: respect, TF-IDF Score: 0.0147
#   Term: empathy, TF-IDF Score: 0.0147
#   Term: referenced, TF-IDF Score: 0.0147
#   Term: plumper, TF-IDF Score: 0.0147
#   Term: gained, TF-IDF Score: 0.0147
#   Term: angelic, TF-IDF Score: 0.0147
#   Term: vaguely, TF-IDF Score: 0.0147
#   Term: backs, TF-IDF Score: 0.0147
#   Term: relatively, TF-IDF Score: 0.0147
#   Term: sport, TF-IDF Score: 0.0147
#   Term: retaining, TF-IDF Score: 0.0147
#   Term: loses, TF-IDF Score: 0.0147
#   Term: degree, TF-IDF Score: 0.0147
#   Term: raising, TF-IDF Score: 0.0147
#   Term: need, TF-IDF Score: 0.0147
#   Term: siphon, TF-IDF Score: 0.0147
#   Term: filled, TF-IDF Score: 0.0147
#   Term: spikes, TF-IDF Score: 0.0147
#   Term: toes, TF-IDF Score: 0.0147
#   Term: rings, TF-IDF Score: 0.0147
#   Term: encased, TF-IDF Score: 0.0147
#   Term: togepī, TF-IDF Score: 0.0147
#   Term: トゲピー, TF-IDF Score: 0.0147
#   Term: book, TF-IDF Score: 0.0143
#   Term: order, TF-IDF Score: 0.0143
#   Term: players, TF-IDF Score: 0.0143
#   Term: bros, TF-IDF Score: 0.0143
#   Term: attack, TF-IDF Score: 0.0143
#   Term: super, TF-IDF Score: 0.0143
#   Term: seen, TF-IDF Score: 0.0143
#   Term: appearing, TF-IDF Score: 0.0143
#   Term: popular, TF-IDF Score: 0.0130
#   Term: gamesradar, TF-IDF Score: 0.0130
#   Term: used, TF-IDF Score: 0.0130
#   Term: including, TF-IDF Score: 0.0130
#   Term: suggesting, TF-IDF Score: 0.0125
#   Term: advanced, TF-IDF Score: 0.0125
#   Term: shape, TF-IDF Score: 0.0125
#   Term: eggo, TF-IDF Score: 0.0125
#   Term: adding, TF-IDF Score: 0.0125
#   Term: lives, TF-IDF Score: 0.0125
#   Term: mischievous, TF-IDF Score: 0.0125
#   Term: area, TF-IDF Score: 0.0125
#   Term: early, TF-IDF Score: 0.0125
#   Term: blasting, TF-IDF Score: 0.0125
#   Term: real, TF-IDF Score: 0.0125
#   Term: talk, TF-IDF Score: 0.0125
#   Term: specific, TF-IDF Score: 0.0125
#   Term: objects, TF-IDF Score: 0.0125
#   Term: luck, TF-IDF Score: 0.0125
#   Term: 100, TF-IDF Score: 0.0125
#   Term: expressions, TF-IDF Score: 0.0125
#   Term: godzilla, TF-IDF Score: 0.0125
#   Term: connection, TF-IDF Score: 0.0125
#   Term: taking, TF-IDF Score: 0.0125
#   Term: rampaging, TF-IDF Score: 0.0125
#   Term: memories, TF-IDF Score: 0.0125
#   Term: born, TF-IDF Score: 0.0125
#   Term: serves, TF-IDF Score: 0.0125
#   Term: padilla, TF-IDF Score: 0.0125
#   Term: raymond, TF-IDF Score: 0.0125
#   Term: elston, TF-IDF Score: 0.0125
#   Term: brett, TF-IDF Score: 0.0125
#   Term: manage, TF-IDF Score: 0.0125
#   Term: birds, TF-IDF Score: 0.0125
#   Term: protection, TF-IDF Score: 0.0125
#   Term: die, TF-IDF Score: 0.0125
#   Term: beanbag, TF-IDF Score: 0.0125
#   Term: occasions, TF-IDF Score: 0.0125
#   Term: carries, TF-IDF Score: 0.0125
#   Term: exposed, TF-IDF Score: 0.0125
#   Term: japanification, TF-IDF Score: 0.0125
#   Term: stay, TF-IDF Score: 0.0125
#   Term: forth, TF-IDF Score: 0.0125
#   Term: acquired, TF-IDF Score: 0.0125
#   Term: max, TF-IDF Score: 0.0125
#   Term: finally, TF-IDF Score: 0.0125
#   Term: meet, TF-IDF Score: 0.0125
#   Term: trying, TF-IDF Score: 0.0125
#   Term: travels, TF-IDF Score: 0.0125
#   Term: receiving, TF-IDF Score: 0.0125
#   Term: field, TF-IDF Score: 0.0125
#   Term: making, TF-IDF Score: 0.0125
#   Term: seasons, TF-IDF Score: 0.0125
#   Term: culture, TF-IDF Score: 0.0125
#   Term: gone, TF-IDF Score: 0.0125
#   Term: honey, TF-IDF Score: 0.0125
#   Term: symbol, TF-IDF Score: 0.0125
#   Term: eat, TF-IDF Score: 0.0125
#   Term: obtaining, TF-IDF Score: 0.0125
#   Term: somewhat, TF-IDF Score: 0.0125
#   Term: wired, TF-IDF Score: 0.0125
#   Term: useless, TF-IDF Score: 0.0125
#   Term: rampage, TF-IDF Score: 0.0125
#   Term: 400, TF-IDF Score: 0.0125
#   Term: violent, TF-IDF Score: 0.0125
#   Term: joy, TF-IDF Score: 0.0125
#   Term: lance, TF-IDF Score: 0.0125
#   Term: calm, TF-IDF Score: 0.0125
#   Term: level, TF-IDF Score: 0.0109
#   Term: coloration, TF-IDF Score: 0.0109
#   Term: legs, TF-IDF Score: 0.0109
#   Term: cute, TF-IDF Score: 0.0109
#   Term: takes, TF-IDF Score: 0.0109
#   Term: favourite, TF-IDF Score: 0.0109
#   Term: creature, TF-IDF Score: 0.0109
#   Term: cards, TF-IDF Score: 0.0109
#   Term: sevii, TF-IDF Score: 0.0109
#   Term: wanted, TF-IDF Score: 0.0109
#   Term: personality, TF-IDF Score: 0.0109
#   Term: resembles, TF-IDF Score: 0.0109
#   Term: harry, TF-IDF Score: 0.0109
#   Term: figure, TF-IDF Score: 0.0109
#   Term: 747, TF-IDF Score: 0.0109
#   Term: tells, TF-IDF Score: 0.0109
#   Term: fellow, TF-IDF Score: 0.0109
#   Term: angry, TF-IDF Score: 0.0109
#   Term: shaped, TF-IDF Score: 0.0109
#   Term: girl, TF-IDF Score: 0.0109
#   Term: quite, TF-IDF Score: 0.0109
#   Term: additionally, TF-IDF Score: 0.0109
#   Term: living, TF-IDF Score: 0.0109
#   Term: bond, TF-IDF Score: 0.0109
#   Term: finds, TF-IDF Score: 0.0109
#   Term: hoenn, TF-IDF Score: 0.0109
#   Term: shows, TF-IDF Score: 0.0109
#   Term: brock, TF-IDF Score: 0.0109
#   Term: pokédex, TF-IDF Score: 0.0109
#   Term: great, TF-IDF Score: 0.0109
#   Term: minor, TF-IDF Score: 0.0109
#   Term: protagonist, TF-IDF Score: 0.0109
#   Term: worlds, TF-IDF Score: 0.0109
#   Term: believe, TF-IDF Score: 0.0109
#   Term: decides, TF-IDF Score: 0.0109
#   Term: meets, TF-IDF Score: 0.0109
#   Term: obtainable, TF-IDF Score: 0.0109
#   Term: continues, TF-IDF Score: 0.0109
#   Term: mini, TF-IDF Score: 0.0109
#   Term: gains, TF-IDF Score: 0.0109
#   Term: flying, TF-IDF Score: 0.0109
#   Term: figurines, TF-IDF Score: 0.0109
#   Term: multiple, TF-IDF Score: 0.0109
#   Term: ign, TF-IDF Score: 0.0108
#   Term: children, TF-IDF Score: 0.0108
#   Term: generation, TF-IDF Score: 0.0108
#   Term: reception, TF-IDF Score: 0.0108
#   Term: manga, TF-IDF Score: 0.0108
#   Term: merchandise, TF-IDF Score: 0.0108
#   Term: later, TF-IDF Score: 0.0108
#   Term: nintendo, TF-IDF Score: 0.0108
#   Term: mr, TF-IDF Score: 0.0097
#   Term: brawl, TF-IDF Score: 0.0097
#   Term: stadium, TF-IDF Score: 0.0097
#   Term: young, TF-IDF Score: 0.0097
#   Term: life, TF-IDF Score: 0.0097
#   Term: capable, TF-IDF Score: 0.0097
#   Term: friend, TF-IDF Score: 0.0097
#   Term: energy, TF-IDF Score: 0.0097
#   Term: playing, TF-IDF Score: 0.0097
#   Term: just, TF-IDF Score: 0.0097
#   Term: major, TF-IDF Score: 0.0097
#   Term: included, TF-IDF Score: 0.0097
#   Term: gets, TF-IDF Score: 0.0097
#   Term: high, TF-IDF Score: 0.0097
#   Term: arms, TF-IDF Score: 0.0097
#   Term: stand, TF-IDF Score: 0.0097
#   Term: small, TF-IDF Score: 0.0097
#   Term: head, TF-IDF Score: 0.0097
#   Term: constant, TF-IDF Score: 0.0097
#   Term: calling, TF-IDF Score: 0.0097
#   Term: sleeping, TF-IDF Score: 0.0097
#   Term: travel, TF-IDF Score: 0.0097
#   Term: choose, TF-IDF Score: 0.0097
#   Term: obtain, TF-IDF Score: 0.0097
#   Term: yellow, TF-IDF Score: 0.0097
#   Term: plush, TF-IDF Score: 0.0097
#   Term: receives, TF-IDF Score: 0.0087
#   Term: debut, TF-IDF Score: 0.0087
#   Term: official, TF-IDF Score: 0.0087
#   Term: light, TF-IDF Score: 0.0087
#   Term: alongside, TF-IDF Score: 0.0087
#   Term: sleep, TF-IDF Score: 0.0087
#   Term: promotion, TF-IDF Score: 0.0087
#   Term: friends, TF-IDF Score: 0.0087
#   Term: melee, TF-IDF Score: 0.0087
#   Term: place, TF-IDF Score: 0.0087
#   Term: revealed, TF-IDF Score: 0.0087
#   Term: ownership, TF-IDF Score: 0.0087
#   Term: considered, TF-IDF Score: 0.0087
#   Term: toys, TF-IDF Score: 0.0087
#   Term: eyes, TF-IDF Score: 0.0079
#   Term: poll, TF-IDF Score: 0.0079
#   Term: released, TF-IDF Score: 0.0079
#   Term: wild, TF-IDF Score: 0.0079
#   Term: given, TF-IDF Score: 0.0079
#   Term: defeated, TF-IDF Score: 0.0079
#   Term: islands, TF-IDF Score: 0.0079
#   Term: ball, TF-IDF Score: 0.0079
#   Term: using, TF-IDF Score: 0.0079
#   Term: poké, TF-IDF Score: 0.0079
#   Term: certain, TF-IDF Score: 0.0079
#   Term: hands, TF-IDF Score: 0.0079
#   Term: west, TF-IDF Score: 0.0079
#   Term: new, TF-IDF Score: 0.0079
#   Term: crystal, TF-IDF Score: 0.0079
#   Term: card, TF-IDF Score: 0.0079
#   Term: imdb, TF-IDF Score: 0.0071
#   Term: use, TF-IDF Score: 0.0071
#   Term: listed, TF-IDF Score: 0.0071
#   Term: able, TF-IDF Score: 0.0071
#   Term: shown, TF-IDF Score: 0.0071
#   Term: rocket, TF-IDF Score: 0.0071
#   Term: evolves, TF-IDF Score: 0.0071
#   Term: said, TF-IDF Score: 0.0071
#   Term: similar, TF-IDF Score: 0.0071
#   Term: trading, TF-IDF Score: 0.0071
#   Term: evolved, TF-IDF Score: 0.0071
#   Term: named, TF-IDF Score: 0.0065
#   Term: black, TF-IDF Score: 0.0065
#   Term: best, TF-IDF Score: 0.0065
#   Term: adventure, TF-IDF Score: 0.0065
#   Term: time, TF-IDF Score: 0.0065
#   Term: dungeon, TF-IDF Score: 0.0065
#   Term: mystery, TF-IDF Score: 0.0065
#   Term: white, TF-IDF Score: 0.0065
#   Term: titles, TF-IDF Score: 0.0065
#   Term: spinoff, TF-IDF Score: 0.0065
#   Term: subsequent, TF-IDF Score: 0.0065
#   Term: created, TF-IDF Score: 0.0065
#   Term: leafgreen, TF-IDF Score: 0.0059
#   Term: firered, TF-IDF Score: 0.0059
#   Term: received, TF-IDF Score: 0.0059
#   Term: sequels, TF-IDF Score: 0.0059
#   Term: freak, TF-IDF Score: 0.0059
#   Term: bulbapedia, TF-IDF Score: 0.0054
#   Term: links, TF-IDF Score: 0.0054
#   Term: external, TF-IDF Score: 0.0054
#   Term: references, TF-IDF Score: 0.0054
#   Term: appearances, TF-IDF Score: 0.0054
#   Term: make, TF-IDF Score: 0.0054
#   Term: team, TF-IDF Score: 0.0054
#   Term: adventures, TF-IDF Score: 0.0054
#   Term: media, TF-IDF Score: 0.0054
#   Term: adaptations, TF-IDF Score: 0.0054
#   Term: printed, TF-IDF Score: 0.0054
#   Term: animated, TF-IDF Score: 0.0054
#   Term: various, TF-IDF Score: 0.0054
#   Term: sugimori, TF-IDF Score: 0.0054
#   Term: ken, TF-IDF Score: 0.0054
#   Term: franchise, TF-IDF Score: 0.0054

# %%
import os
from sklearn.feature_extraction.text import TfidfVectorizer

# Path to the folder containing the text files
folder_path = 'Data'

# Function to read the content of all documents
def read_documents(folder_path):
    documents = []
    filenames = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                content = file.read()
                documents.append(content)
                filenames.append(filename)
    return documents, filenames

# Read the documents
documents, filenames = read_documents(folder_path)

# Create a TfidfVectorizer instance
vectorizer = TfidfVectorizer(stop_words='english')

# Fit the vectorizer and transform the documents into TF-IDF features
tfidf_matrix = vectorizer.fit_transform(documents)

# Get the feature names (terms)
terms = vectorizer.get_feature_names_out()

# Open a text file to store the output
with open('TF-IDF.txt', 'w') as output_file:
    output_file.write("TF-IDF Features for Each Document:\n")
    
    # Store TF-IDF features for each document
    for i, filename in enumerate(filenames):
        output_file.write(f"\nDocument: {filename}\n")
        feature_index = tfidf_matrix[i, :].nonzero()[1]
        tfidf_scores = zip(feature_index, [tfidf_matrix[i, x] for x in feature_index])
        for idx, score in sorted(tfidf_scores, key=lambda x: -x[1]):
            output_file.write(f"  Term: {terms[idx]}, TF-IDF Score: {score:.4f}\n")

print("TF-IDF features saved to 'TF-IDF.txt'.")
# Out:
# TF-IDF features saved to 'TF-IDF.txt'.

# %% [markdown]
# Compute the Cosine Similarity

# %%
import os
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Path to the folder containing the text files
folder_path = 'Data'

# Function to read the content of all documents
def read_documents(folder_path):
    documents = []
    filenames = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                content = file.read()
                documents.append(content)
                filenames.append(filename)
    return documents, filenames

# Read the documents
documents, filenames = read_documents(folder_path)

# Create a TfidfVectorizer instance
vectorizer = TfidfVectorizer(stop_words='english')

# Fit the vectorizer and transform the documents into TF-IDF features
tfidf_matrix = vectorizer.fit_transform(documents)

# Compute the cosine similarity matrix
similarity_matrix = cosine_similarity(tfidf_matrix)

# Save the similarity matrix to a file
with open('Cosine_Similarity_Matrix.txt', 'w') as output_file:
    output_file.write("Cosine Similarity Matrix for the Document Corpus:\n\n")

    # Write the header (filenames)
    output_file.write("\t" + "\t".join(filenames) + "\n")
    
    # Write the similarity scores for each document pair
    for i, filename in enumerate(filenames):
        similarity_scores = "\t".join([f"{similarity_matrix[i, j]:.4f}" for j in range(len(filenames))])
        output_file.write(f"{filename}\t{similarity_scores}\n")

print("Cosine similarity matrix saved to 'Cosine_Similarity_Matrix.txt'.")
# Out:
# Cosine similarity matrix saved to 'Cosine_Similarity_Matrix.txt'.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
